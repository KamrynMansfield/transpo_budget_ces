# %% [markdown]
# # Lit Review Table
#
# Kamryn Mansfield

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.2
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# Read in the csv of the lit review table:

# %%
lit_tbl <- read_csv("lit_review_table.csv") |>
  select(Title, Citation = `bibtex name`, Dataset, Findings = `Main Findings`)
# Out:
# Rows: 35 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (10): Author, Title, bibtex name, Brief summary of what the study is abo...
# dbl (11): Study Number, Year, Use Consumer Expenditure Survey Data?, Transpo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# Output the table:

# %%
kable(lit_tbl)
# Out:
#   ------------------------------------------------------------------------------------------------------------------------------------
#   Title                Citation                                                   Dataset        Findings
#   -------------------- ---------------------------------------------------------- -------------- -------------------------------------
#   A family expenditure @morris_family_1979                                        Australian     transport takes about o17 percent of
#   perspective on                                                                  Expenditure    expenditures, at least part of the
#   transport planning:                                                             Survey         consumption expenditure by low income
#   Australian evidence                                                                            families is financed from savings,
# ...
