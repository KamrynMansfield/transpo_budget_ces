# %% [markdown]
# # Lit Review Table
#
# Kamryn Mansfield

# %%
library(tidyverse)
# Out:
# Warning: package 'tibble' was built under R version 4.5.2
# Warning: package 'tidyr' was built under R version 4.5.2
# Warning: package 'purrr' was built under R version 4.5.2
# Warning: package 'dplyr' was built under R version 4.5.2
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.6.0
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Warning: package 'knitr' was built under R version 4.5.2

# %% [markdown]
# Read in the csv of the lit review table:

# %%
lit_tbl <- read_csv("lit_review_table2.csv")
# Out:
# Rows: 35 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): Study, Category
# lgl (1): Uses CEX Data
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# Output the table:

# %%
#| label: tbl-lit-summary
#| tbl-cap: "Summary of the Literature"
#| tbl-alt: "A table listing and describing the literature used in this review"

lit_tbl |>
  group_by(Category, `Uses CEX Data`) |>
  summarize(Studies = paste(Study, collapse = ", ")) |>
  kable()
# Out:
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by Category and Uses CEX Data.
# ℹ Output is grouped by Category.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(Category, Uses CEX Data))` for per-operation grouping
#   (`?dplyr::dplyr_by`) instead.
#   ----------------------------------------------------------------------------------------
#   Category         Uses    Studies
#                    CEX
#                    Data
#   ---------------- ------- ---------------------------------------------------------------
#   Budgets          FALSE   @duncan_estimating_2023, @hargunani_study_2024
#
#   Budgets          TRUE    @skinner_variable_1985, @nayga_sample_1998,
#                            @fontes_effects_2006, @sabelhaus_is_2013,
#                            @lino_expenditures_2017, @osborne_updated_2021,
#                            @hastings_parental_2022
#
#   Household        FALSE   @sener_analysis_2007, @copperman_exploratory_2007,
#   Choices                  @sener_analysis_2008, @paleti_empirical_2011,
#                            @bernardo_empirical_2015, @leung_environment-people_2019
#
#   Transportation   FALSE   @copperman_analysis_2007, @souche_measuring_2010,
#                            @mccarthy_factors_2017, @lu_role_2022,
#                            @amirnazmiafshar_review_2022, @klein_subsidizing_2024,
#                            @bilgin_investigating_2025
#
#   Transportation   FALSE   @morris_family_1979
#   and Budgets
#
#   Transportation   TRUE    @blumenberg_transportation_2003, @thakuriah_analysis_2005,
#   and Budgets              @hong_leisure_2005, @thakuriah_vonu_transportation_2006,
#                            @choo_transportation_2007, @haas_estimating_2008,
#                            @ferdous_comprehensive_2010, @deka_relationship_2015,
#                            @mattson_relationships_2019, @mattson_relationships_2020,
#                            @molloy_new_2024,
#                            @bureau_of_transportation_statistics_transportation_2024
#   ----------------------------------------------------------------------------------------
