# %% [markdown]
# # Lit Review Table
#
# Kamryn Mansfield

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.2
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# Read in the csv of the lit review table:

# %%
lit_tbl <- read_csv("lit_review_table.csv") |>
  select(Title, Authors = Author, citation = `bibtex name`, Year, Dataset, Findings = `Main Findings`)
# Out:
# Rows: 35 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (10): Author, Title, bibtex name, Brief summary of what the study is abo...
# dbl (11): Study Number, Year, Use Consumer Expenditure Survey Data?, Transpo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# Output the table:

# %%
#| label: tbl-lit-summary
#| tbl-cap: "Summary of the Literature"
#| tbl-alt: "A table listing and describing the literature used in this review"

kable(lit_tbl)
# Out:
#   ----------------------------------------------------------------------------------------------------------------------------------------------------------
#   Title                Authors             citation                                                     Year Dataset        Findings
#   -------------------- ------------------- ---------------------------------------------------------- ------ -------------- --------------------------------
#   A family expenditure Morris, J. M., &    @morris_family_1979                                          1979 Australian     transport takes about o17
#   perspective on       Wigan, M. R.                                                                          Expenditure    percent of expenditures, at
#   transport planning:                                                                                        Survey         least part of the consumption
#   Australian evidence                                                                                                       expenditure by low income
#   in context                                                                                                                families is financed from
#                                                                                                                             savings, loans or other sourCEX
#                                                                                                                             besides "income".
#
#   Variable Lifespan    Skinner             @skinner_variable_1985                                       1985 CEX            Changes in inflation will prompt
#   and the                                                                                                                   changes in consumer expenditures
#   Intertemporal
#   Elasticity of
#   Consumption
#
#   A sample selection   Nayga               @nayga_sample_1998                                           1998 CEX            Most of the variables analysed
#   model for prepared                                                                                                        significantly affect prepared
#   food expenditures                                                                                                         food expenditures. For example,
#                                                                                                                             results suggest that frozen
#                                                                                                                             meals expenditures are higher
#                                                                                                                             for households without children,
#                                                                                                                             for smaller households, and for
#                                                                                                                             households headed by a non-white
#                                                                                                                             individual
#
#   Transportation Costs Blumenberg, E.      @blumenberg_transportation_2003                              2003 CEX            Cost comparisons fall short of
#   and Economic                                                                                                              finding if transportation costs
#   Opportunity Among                                                                                                         are a barrier for economic
#   the Poor                                                                                                                  opportunity among the poor
#
#   Analysis of          Thakuriah, P.       @thakuriah_vanu_analysis_2005                                2005 CEX            For vehicle-owning households,
#   Variations in        (Vonu), & Liao, Y.                                                                                   of every additional dollar that
#   Vehicle Ownership                                                                                                         households spend, 18 cents is
#   Expenditures                                                                                                              spent on vehicles after
#                                                                                                                             controlling for socioeconomic,
#                                                                                                                             demographic, life cycle, and
#                                                                                                                             other factors relating to
#                                                                                                                             households.
#
#   Leisure Travel       Hong, G.-S., Fan,   @hong_leisure_2005                                           2005 CEX            Marrieds without children are
#   Expenditure Patterns J. X., Palmer, L.,                                                                                   more likely to spend on leisure
#   by Family Life Cycle & Bhargava, V.                                                                                       travel than singles, whereas
#   Stages                                                                                                                    single parents and solitary
#                                                                                                                             survivors are less likely to
#                                                                                                                             spend on leisure travel than
#                                                                                                                             singles.
#
#   Transportation       Thakuriah (Vonu),   @thakuriah_vonu_transportation_2006                          2006 CEX            Transportation expenditures made
#   Expenditures and     P., & Liao, Y.                                                                                       by households are better
#   Ability to Pay:                                                                                                           explained by permanent income
#   Evidence from                                                                                                             levels of households than by
#   Consumer Expenditure                                                                                                      annual incomes.
#   Survey
#
#   The Effects of       Fontes and Fan      @fontes_effects_2006                                         2006 CEX            Asian Americans allocate more of
#   Ethnic Identity on                                                                                                        their budget to housing, African
#   Household Budget                                                                                                          Americans allocate more of their
#   Allocation to Status                                                                                                      budget to apparel, and Hispanics
#   Conveying Goods                                                                                                           allocate more of their budget to
#                                                                                                                             both housing and apparel, but to
#                                                                                                                             a lesser extent than Asian
#                                                                                                                             Americans with respect to
#                                                                                                                             housing and African Americans
#                                                                                                                             with respect to apparel.
#
#   Do Transportation    Choo, S., Lee, T.,  @choo_transportation_2007                                    2007 CEX            New tech doesn't substitue
#   and Communications   & Mokhtarian, P. L.                                                                                  Personal Vehicle travel probably
#   Tend to be
#   Substitutes,
#   Complements, or
#   Neither?: U.S.
#   Consumer
#   Expenditures
#   Perspective,
#   1984--2002
#
#   An analysis of the   Copperman, R. B., & @copperman_analysis_2007                                     2007 San Francisco  The "number of children"
#   determinants of      Bhat, C. R.                                                                           Bay Area       variable suggests an overall
#   children's weekend                                                                                         Travel Survey  higher likelihood of
#   physical activity                                                                                                         participation in utilitarian
#   participation                                                                                                             active travel among households
#                                                                                                                             with many children relative to
#                                                                                                                             households with few children
#
#   An analysis of the   Sener, I. N., &     @sener_analysis_2007                                         2007 Panel Study of male children more likely to
#   social context of    Bhat, C. R.                                                                           Income         participate with their fathers
#   children's weekend                                                                                         Dynamics       than female children,
#   discretionary                                                                                              (PSID)         African-American children less
#   activity                                                                                                                  likely to participate in
#   participation                                                                                                             health-enhancing active
#                                                                                                                             recreation pursuits
#
#   An Exploratory       Copperman, R. B., & @copperman_exploratory_2007                                  2007 Panel Study of The age of childrend has an
#   Analysis of          Bhat, C. R.                                                                           Income         effect on the types of
#   Children's Daily                                                                                           Dynamics       activities they pursue
#   Time-Use and                                                                                               (PSID)
#   Activity Patterns
#   Using the Child
#   Development
#   Supplement (CDS) to
#   the US Panel Study
#   of Income Dynamics
#   (PSID)
#
#   Estimating           Haas, P. M.,        @haas_estimating_2008                                        2008 CEX and others Their model can help in travel
#   Transportation Costs Makarewicz, C.,                                                                                      demand modeling
#   by Characteristics   Benedict, A., &
#   of Neighborhood and  Bernstein, S.
#   Household
#
#   An analysis of       Sener, I. N.,       @sener_analysis_2008                                         2008 Panel Study of Children in households with
#   children's leisure   Copperman, R. B.,                                                                     Income         parents who are employed, higher
#   activity engagement: Pendyala, R. M., &                                                                    Dynamics       income, or higher education were
#   Examining the day of Bhat, C. R.                                                                           (PSID)         found to participate in
#   week, location,                                                                                                           structured outdoor activities at
#   physical activity                                                                                                         higher rates.
#   level, and fixity
#   dimensions
#
#   A comprehensive      Ferdous, N.,        @ferdous_comprehensive_2010                                  2010 CEX            Adjustments are made with
#   analysis of          Pinjari, A. R.,                                                                                      increased fuel priCEX
#   household            Bhat, C. R., &
#   transportation       Pendyala, R. M.
#   expenditures
#   relative to other
#   goods and serviCEX:
#   An application to
#   United States
#   consumer expenditure
#   data
#
#   Measuring the        Souche, Stephanie   @souche_measuring_2010                                       2010 IUTP database  urban density and cost of
#   Structureal                                                                                                               transport mode were
#   Determinants of                                                                                                           statisticalliy significan in
#   Urban Travel Demand                                                                                                       their model
#
#   An empirical         Paleti, R.,         @paleti_empirical_2011                                       2011 Panel Study of The results show that a wide
#   analysis of          Copperman, R. B., &                                                                   Income         variety of demographic,
#   children's after     Bhat, C. R.                                                                           Dynamics       attitudinal, environmental, and
#   school out-of-home                                                                                         (PSID)         others' activity-travel pattern
#   activity-location                                                                                                         characteristics impact
#   engagement patterns                                                                                                       children's after school activity
#   and time allocation                                                                                                       engagement patterns.
#
#   Is the Consumer      Sabelhaus, J.,      @sabelhaus_is_2013                                           2013 CEX            the highest income thresholds
#   Expenditure Survey   Johnson, D., Ash,                                                                                    are underrepresented in the
#   Representative by    S., Swanson, D.,                                                                                     survey
#   Income?              Garner, T.,
#                        Greenlees, J., &
#                        Henderson, S.
#
#   Relationship between Deka, D.            @deka_relationship_2015                                      2015 CEX            More housing costs = more
#   Households' Housing                                                                                                       transportation costs, people the
#   and Transportation                                                                                                        take transit spend less on
#   Expenditures:                                                                                                             transportation
#   Examination from
#   Lifestyle
#   Perspective
#
#   An empirical         Bernardo, C.,       @bernardo_empirical_2015                                     2015 ATUS           the presence of a child in
#   investigation into   Paleti, R., Hoklas,                                                                                  dual-earner households not only
#   the time-use and     M., & Bhat, C.                                                                                       leads to a reduction in in-home
#   activity patterns of                                                                                                      non-work activity participation
#   dual-earner couples                                                                                                       (excluding child care
#   with and without                                                                                                          activities) but also a
#   young children                                                                                                            substantially larger decrease in
#                                                                                                                             out-of-home non-work activity
#                                                                                                                             participation (excluding child
#                                                                                                                             care and shopping activities),
#
#   Expenditures on      Lino, M.,           @lino_expenditures_2017                                      2017 CEX            Many observations on the
#   Children by          Kuczynski, K.,                                                                                       expenditures of children
#   Families, 2015       Rodriguez, N., &
#                        Schap, T.
#
#   Factors influencing  McCarthy, L.,       @mccarthy_factors_2017                                       2017 Lit Review     many factores influence
#   travel mode choice   Delbosc, A.,                                                                                         decisions about mode choice when
#   among families with  Currie, G., &                                                                                        traveling with young children.
#   young children (aged Molloy, A.
#   0--4): A review of
#   the literature
#
#   Relationships        Mattson, J., &      @mattson_relationships_2019                                  2019 CEX, Ammerican denser areas are more likely to
#   between Land Use,    Peterson, D.                                                                          Community      use transit to commute. People
#   Transportation,                                                                                            Survey         in single-family homes tend to
#   Household                                                                                                                 spend more money on
#   Expenditures, and                                                                                                         transportation
#   Municipal Spending
#   in Small Urban Areas
#
#   An                   Leung, K. Y. K.,    @leung_environment-people_2019                               2019 Survey in Hong childrens activities can differ
#   environment-people   Astroza, S., Loo,                                                                     Kong Schools   a lot based on neighborhood
#   interactions         B. P. Y., & Bhat,                                                                                    enfironment and family
#   framework for        C. R.                                                                                                sociodemographic background.
#   analysing children's
#   extra-curricular
#   activities and
#   active transport
#
#   Relationships        Mattson, J.         @mattson_relationships_2020                                  2020 CEX, Ammerican single family homes spend more
#   between density,                                                                                           Community      on transportation, higher income
#   transit, and                                                                                               Survey         is correlated with higher
#   household                                                                                                                 tranportation costs.
#   expenditures in
#   small urban areas
#
#   An Updated           Osborne, C., Wu,    @osborne_updated_2021                                        2021 NHTS, CEX      Regardless of the method of
#   Estimation Model of  E., & Benson, K.                                                                                     calculation, we find that it is
#   the Cost of Raising                                                                                                       nearly impossible for two
#   Children in Texas                                                                                                         minimum wage earners to meet the
#                                                                                                                             basic costs of raising children
#                                                                                                                             in Texas, especially when child
#                                                                                                                             care is included
#
#   Parental Investments Hastings, O. P.     @hastings_parental_2022                                      2022 CEX            . Both sociodemographic and
#   of Money for White,                                                                                                       economic factors play a
#   Black, and Hispanic                                                                                                       substantial role in these
#   Children in the                                                                                                           differenCEX, and the racial and
#   United States                                                                                                             ethnic gaps in parental
#                                                                                                                             investments of money are nearly
#                                                                                                                             eliminated when both are
#                                                                                                                             accounted for
#
#   The role of          Lu, Y., Prato, C.   @lu_role_2022                                                2022 Southeast      joint travel contributes least
#   household modality   G., Sipe, N.,                                                                         Queensland     to modal shift from car to
#   style in first and   Kimpton, A., &                                                                        Travel Survey  active transport when there is
#   last mile travel     Corcoran, J.                                                                          (SEQTS)        improved infrastructure of
#   mode choice                                                                                                               trains and things
#
#   A review of the      Amirnazmiafshar,    @amirnazmiafshar_review_2022                                 2022 NA             There are lots of factors that
#   socio-demographic    E., & Diana, M.                                                                                      might affect people's
#   characteristics                                                                                                           willingness to use car sharing
#   affecting the demand
#   for different
#   car-sharing
#   operational schemes
#
#   Estimating           Duncan, K. A.,      @duncan_estimating_2023                                      2023 Survey of      The more income, the more
#   Expenditures on      Frank, K., &                                                                          Household      spending on kids.
#   Children by Families Guèvremont, A.                                                                        Spending (SHS)
#   in Canada, 2014 to
#   2017
#
#   A New Approach to    Molloy, Q.,         @molloy_new_2024                                             2024 CEX            "Captive Riders" have less
#   Understanding the    Garrick, N., &                                                                                       spending allocated to
#   Impact of Automobile Atkinson-Palombo,                                                                                    transportation than captive
#   Ownership on         C.                                                                                                   drivers.
#   Transportation
#   Equity
#
#   Transportation       Bureau of           @bureau_of_transportation_statistics_transportation_2024     2024 CEX and others Lots of summaries
#   Statistics Annual    Transportation
#   Report 2024          Statistics.
#
#   A STUDY OF SPENDING, Hargunani, C.,      @hargunani_study_2024                                        2024 Data from      The data analysis reveals
#   SAVING AND           Vernekar, S., &                                                                       Mumbai         distinct spending, saving, and
#   INVESTMENT PATTERNS  Vernekar, S.                                                                                         investment patterns among
#   OF MARRIED COUPLES                                                                                                        married couples, with a clear
#   WITH                                                                                                                      prioritization towards ensuring
#   CHILDREN(NON-DINK)                                                                                                        the well-being and future
#   IN MUMBAI                                                                                                                 security of their families."
#
#   Subsidizing Car      Klein, N. J.        @klein_subsidizing_2024                                      2024 Personal       Having a car gave people more
#   Ownership for                                                                                              Survey Created opportunities than before, and
#   Low-Income                                                                                                 by Dr. Klein   they usually had more time to
#   Individuals and                                                                                                           spend with the family. At the
#   Households                                                                                                                beginning and end of the day.
#
#   Investigating the    Bilgin, P.,         @bilgin_investigating_2025                                   2025 United Kingdom Suggests that households are
#   effects of           Mattioli, G.,                                                                         Household      less likely to qcquire a car in
#   ridesourcing on the  Morgan, M., &                                                                         Longitudinal   the presence of ridesourcing,
#   dynamics of          Wadud, Z.                                                                             Study          but car disposal is mainly
#   household car                                                                                                             driven by household compositions
#   ownership                                                                                                                 and residential relocation
#                                                                                                                             factors.
#   ----------------------------------------------------------------------------------------------------------------------------------------------------------
