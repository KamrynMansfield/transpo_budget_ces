# %% [markdown]
# # Unpacking Household Budgeting Strategies through a Transportation Lens
#
# Kamryn Mansfield [![](data:image/png;base64,...)](https://orcid.org/0009-0003-5466-0821) (University of Tennessee)
# Katie Asmussen [![](data:image/png;base64,...)](https://orcid.org/0000-0002-5615-0708) (University of Tenenessee)
# March 13, 2026
#
# This is where we will put our abstract.

# %%
# loading packages
library(tidyverse)
# Out:
# ...
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.6.0
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ...

# %% [markdown]
# ## 1 Introduction
#
# Households juggle how to allocate their budgets: whether to invest in a reliable car, pay for quality childcare, secure housing in a good school district, or set money aside for leisure. These everyday choices shape how families live and move, reflecting the trade-offs they make to balance competing priorities. Transportation often sits at the center of these decisions, not only because it can be a significant expense, but also because choosing to buy and maintain a car versus relying on public transit represents a long-term commitment and a broader lifestyle choice. The way U.S. households choose to spend their money provides evidence of the weight of transportation decisions in a household. For the last 20 years, the average household has allocated between 15 and 20 percent of its budget on transportation expenditures ([Bureau of Transportation Statistics 2024](#ref-bureau_of_transportation_statistics_transportation_2024)). That is almost double what it was 100 years ago ([Johnson et al. 2001](#ref-johnson_century_2001)). This means that either families are traveling more than they used to or that transportation has become more expensive compared to other household expenditures. Either way, the amount of budget that is put towards a household’s travel indicates that transportation is an important part of a family’s daily life. The fact that lower income households often have a larger portion of their budget spent on transportation further shows the major role it plays in household decisions and suggests that transportation decisions might have a broader effect on other household expenditures ([Molloy et al. 2024](#ref-molloy_new_2024)).
#
# While transportation is a big portion of the average household’s budget, its relative weight compared to housing, childcare, and other spending varies widely across families. Household characteristics like family size, income, car ownership, and location play a role in how much they spend on transportation. For example, people with bigger families or living in single-family homes tend to spend more on transportation ([Mattson 2020](#ref-mattson_relationships_2020)). The relationship between household budgeting and mobility is shaped not only by household demographics but also by how families prioritize and weight different needs. On one hand, mobility resources such as car ownership can structure the household budget: households with no or only one vehicle may spend far less on transportation, freeing up income for other essential or discretionary categories. On the other hand, underlying family structures and preferences can drive budget allocation choices that, in turn, shape transportation behavior. Larger families may prioritize childcare or invest in higher-quality housing in areas with better schools, limiting what remains for transportation. Others may emphasize frugality across all categories or deliberately substitute toward lower-cost transit options. Understanding both the direction of influence and the weight assigned to different budget categories is critical for transportation planning and policy, as these dynamics reveal how families navigate competing priorities under varying demographic and mobility contexts.
#
# The purpose of this research is to explore how household budgets are structured around transportation decisions and how this impacts other spending categories. Using the Consumer Expenditure Survey (CEX), we will perform a Latent Class Analysis (LCA) to find groupings based on a household’s transportation expenses. These groupings can help us find groups of spenders with similar patterns to help us predict transportation expenses based on the household’s characteristics.
#
# *Things I haven’t included but could maybe include in the future?*
#
# - Since 1960, a larger percent of US households have at least one car. It was in the 80s when the percentage of 2-car households surpassed the percentage of 1-car households ([Bureau of Transportation Statistics 2024](#ref-bureau_of_transportation_statistics_transportation_2024))
#
# ## 2 Literature Review

# %%
lit_rev_tbl <- read_csv("notebooks/lit_review_table2.csv")
# Out:
# Rows: 35 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): Study, Category
# lgl (1): Uses CEX Data
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# <a href="#tbl-lit-summary" class="quarto-xref">Table 1</a> summarizes the literature that was reviewed for this study. As seen in the table, there were a total of 35 studies reviewed with 19 studies that use the consumer expenditure survey. The literature relating to this study has been classified into four categories: (1) Household Choices and Activity Patterns, (2) Household Transportation Choices, (3) Household Spending and Budgets, and (4) Household Transportation Budgets. The following sections describe the relevant findings from literature in each of these groups.
#
# ``` python
# kable(lit_tbl)
# ```
#
# | Study | Uses CEX Data | Category |
# |:--------------------------------------------|:---------|:---------------|
# | Morris and Wigan ([1979](#ref-morris_family_1979)) | FALSE | Transportation and Budgets |
# | Skinner ([1985](#ref-skinner_variable_1985)) | TRUE | Budgets |
# | Nayga ([1998](#ref-nayga_sample_1998)) | TRUE | Budgets |
# | Blumenberg ([2003](#ref-blumenberg_transportation_2003)) | TRUE | Transportation and Budgets |
# | Thakuriah and Liao ([2005](#ref-thakuriah_analysis_2005)) | TRUE | Transportation and Budgets |
# | Hong et al. ([2005](#ref-hong_leisure_2005)) | TRUE | Transportation and Budgets |
# | Thakuriah (Vonu) and Liao ([2006](#ref-thakuriah_vonu_transportation_2006)) | TRUE | Transportation and Budgets |
# | Fontes and Fan ([2006](#ref-fontes_effects_2006)) | TRUE | Budgets |
# | Choo et al. ([2007](#ref-choo_transportation_2007)) | TRUE | Transportation and Budgets |
# | Rachel B. Copperman and Bhat ([2007a](#ref-copperman_analysis_2007)) | FALSE | Transportation |
# | Sener and Bhat ([2007](#ref-sener_analysis_2007)) | FALSE | Household Choices |
# | Rachel B. Copperman and Bhat ([2007b](#ref-copperman_exploratory_2007)) | FALSE | Household Choices |
# | Haas et al. ([2008](#ref-haas_estimating_2008)) | TRUE | Transportation and Budgets |
# | Sener et al. ([2008](#ref-sener_analysis_2008)) | FALSE | Household Choices |
# | Ferdous et al. ([2010](#ref-ferdous_comprehensive_2010)) | TRUE | Transportation and Budgets |
# | Souche ([2010](#ref-souche_measuring_2010)) | FALSE | Transportation |
# | Paleti et al. ([2011](#ref-paleti_empirical_2011)) | FALSE | Household Choices |
# | Sabelhaus et al. ([2013](#ref-sabelhaus_is_2013)) | TRUE | Budgets |
# | Deka ([2015](#ref-deka_relationship_2015)) | TRUE | Transportation and Budgets |
# | Bernardo et al. ([2015](#ref-bernardo_empirical_2015)) | FALSE | Household Choices |
# | Lino et al. ([2017](#ref-lino_expenditures_2017)) | TRUE | Budgets |
# | McCarthy et al. ([2017](#ref-mccarthy_factors_2017)) | FALSE | Transportation |
# | Mattson and Peterson ([2019](#ref-mattson_relationships_2019)) | TRUE | Transportation and Budgets |
# | Leung et al. ([2019](#ref-leung_environment-people_2019)) | FALSE | Household Choices |
# | Mattson ([2020](#ref-mattson_relationships_2020)) | TRUE | Transportation and Budgets |
# | Osborne et al. ([2021](#ref-osborne_updated_2021)) | TRUE | Budgets |
# | Hastings ([2022](#ref-hastings_parental_2022)) | TRUE | Budgets |
# | Lu et al. ([2022](#ref-lu_role_2022)) | FALSE | Transportation |
# | Amirnazmiafshar and Diana ([2022](#ref-amirnazmiafshar_review_2022)) | FALSE | Transportation |
# | Duncan et al. ([2023](#ref-duncan_estimating_2023)) | FALSE | Budgets |
# | Molloy et al. ([2024](#ref-molloy_new_2024)) | TRUE | Transportation and Budgets |
# | Bureau of Transportation Statistics ([2024](#ref-bureau_of_transportation_statistics_transportation_2024)) | TRUE | Transportation and Budgets |
# | Hargunani et al. ([2024](#ref-hargunani_study_2024)) | FALSE | Budgets |
# | Klein ([2024](#ref-klein_subsidizing_2024)) | FALSE | Transportation |
# | Bilgin et al. ([2025](#ref-bilgin_investigating_2025)) | FALSE | Transportation |
#
# Table 1: Summary of the Literature
#
# ### 2.1 Household Activities and Transportation Choices
#
# The literature shows that household dynamics affect the activity patterns of those in the household, and many studies focus on the role children play in these household activities. Some studies aim to find how the presence of children affect the activities of the household ([Bernardo et al. 2015](#ref-bernardo_empirical_2015)), and many studies focus on how children’s activities are affected by household demographics (see [Sener and Bhat 2007](#ref-sener_analysis_2007); [Rachel B. Copperman and Bhat 2007b](#ref-copperman_exploratory_2007); [Sener et al. 2008](#ref-sener_analysis_2008); [Paleti et al. 2011](#ref-paleti_empirical_2011); [Leung et al. 2019](#ref-leung_environment-people_2019)). A common finding in these studies is that child activity participation is associated with the environment the child lives in along with household income, parent activities, and other household demographics.
#
# Among the studies on household choices is a group of literature with a specific focus on a household’s transportation decisions. A common finding in this group of literature is that household composition plays a role in its transportation choices. Some studies in this group are concerned with the way households use cars or the effect of car ownership on transportation decisions ([Lu et al. 2022](#ref-lu_role_2022); [Amirnazmiafshar and Diana 2022](#ref-amirnazmiafshar_review_2022); [Klein 2024](#ref-klein_subsidizing_2024); [Bilgin et al. 2025](#ref-bilgin_investigating_2025)). These studies show there is a major connection between car ownership and transportation decisions. Other studies are focused on travel choices more generally ([Rachel B. Copperman and Bhat 2007a](#ref-copperman_analysis_2007); [Souche 2010](#ref-souche_measuring_2010)). For an extensive literature review on the transportation choices of households with young children, see the study done by McCarthy et al. ([2017](#ref-mccarthy_factors_2017)).
#
# ### 2.2 Household Spending and Budgets
#
# Another set of studies focuses on household budgets and household spending patterns ([Skinner 1985](#ref-skinner_variable_1985); [Nayga 1998](#ref-nayga_sample_1998); [Fontes and Fan 2006](#ref-fontes_effects_2006); [Sabelhaus et al. 2013](#ref-sabelhaus_is_2013)). Many of the studies reviewed had an emphasis on the budgets related to raising children. Hargunani et al. ([2024](#ref-hargunani_study_2024)) analyzed family spending patterns in Mumbai and concluded that many families focus their expenditures on the current and future wellbeing of their children. This is evidenced by money spent on basic necessities and setting aside money for the future.
#
# The United States Department of Agriculture (USDA) has produced reports that use the CEX to specifically analyze the costs of raising a child in the United States. The most recent report ([Lino et al. 2017](#ref-lino_expenditures_2017)) found the top expenditure for married-couple families with two children to be housing. The rankings of other expenditures were different depending on the age of children, but food, child care/education, and transportation were always the next highest expenditures on children. Similar to the USDA report on the cost of raising children, Osborne et al. ([2021](#ref-osborne_updated_2021)) modeled the cost of raising children in Texas by following similar methodologies but using Texas-specific data for housing and childcare costs. They looked not only at married-couple families, but also at single-parent households and duel households where children spend time with both parents in different locations. They found differing expenditures on children among the different family make-ups and among different incomes.
#
# Duncan et al. ([2023](#ref-duncan_estimating_2023)) performed a study in Canada using the country’s Survey of Household Spending (SHS) to analyze family expenditures. They found similar results as previously mentioned studies. Different income groups had different amounts allocated to children, but housing was always the highest expenditure with food, child care/education, and transportation being the next highest expenditures.
#
# Other studies with similar analyses have had similar findings. Hastings ([2022](#ref-hastings_parental_2022)) used the CEX to compare expenditures between different racial and ethnic groups. When controlling for both family characteristics and income, he found that there was not a significant difference in total expenditures on children among racial and ethnic groups. This suggests that income and family characteristics play a larger role in family budgeting than race and ethnicity.
#
# ### 2.3 Household Transportation Expenses and Budgets
#
# There have been many studies on family budgets and transportation expenses ([Morris and Wigan 1979](#ref-morris_family_1979); [Blumenberg 2003](#ref-blumenberg_transportation_2003); [Hong et al. 2005](#ref-hong_leisure_2005); [Thakuriah (Vonu) and Liao 2006](#ref-thakuriah_vonu_transportation_2006); [Choo et al. 2007](#ref-choo_transportation_2007); [Haas et al. 2008](#ref-haas_estimating_2008); [Ferdous et al. 2010](#ref-ferdous_comprehensive_2010)).
#
# One study focused on transportation budgets was done by Thakuriah and Liao ([2005](#ref-thakuriah_analysis_2005)). Using CEX data, they made multiple models to analyze the expenditures related to vehicle ownership of households in the United States. In each model, they used a variety of variables (income, household demographics, spatial factors, economic factors, and family condition factors) to predict the amount of money a household spends on vehicles. Their model results indicate 18 percent of additional household expenditures is a vehicle expense. The results also indicate many factors influence household vehicle expenses. The models showed that homeowners spend more on vehicle expenses. They also showed that vehicle expenses are connected with the sex of the head of household and the number of people in the household.
#
# In a study by Deka ([2015](#ref-deka_relationship_2015)), they used two years of the CEX to see the connection between housing expenses and transportation expenses. They created three least squares models: one to describe expenditures in dollar amounts, one to describe expenditures as percentages of income, and one to describe expenditures as shares of total household expenditures. They found a positive association between transportation expenses and housing expenses. Similarly, share of income on transportation was positively affected by share of income on housing, but there was no significant evidence showing the share of income on housing being affected by share of income on transportation. Both housing and transportation expenditures were found to be higher for those living in single-family detached homes and lower for those living in older homes.
#
# Mattson and Peterson ([2019](#ref-mattson_relationships_2019)) looked at how density, land use, transportation, and household expenditures are related. They developed a regression model using CEX data where transportation expenditures were estimated using type of housing, population, family characteristics, and other factors. Similar to other studies, they found that income is positively associated with transportation expenditures. Their model showed single-family homes to have higher transportation expenditures than other types of dwellings. Using data from the U.S. Census Bureau’s Annual Survey of State and Local Government Finances, they also created models to explore how land use might affect municipal spending. In these models, increase in density was associated with a decrease in many per capita operational costs, including fire protection, streets and highways, parks and recreation, and others.
#
# A similar study was published by Mattson ([2020](#ref-mattson_relationships_2020)) where he modeled transportation expenditures using CEX data. The results showed, like the previous publication, that single-family dwellings spend more on transportation compared to other types. He also found that larger household sizes and newer homes contribute to higher transportation spending.
#
# In their study, Molloy et al. ([2024](#ref-molloy_new_2024)) look at CEX data after proposing a new framework to look at transit users and vehicle users. In past studies, three categories have been used to analyze transportation users: “drivers” are those who own a car, “captive riders” are those who use transit because they ca not afford a car, and “choice riders” are those who can afford a car but do not. Instead of having one grouping for those that own cars, Molloy et al. ([2024](#ref-molloy_new_2024)) propose splitting that category into “captive drivers” and “choice drivers”. Captive drivers would be those in the population that are low income but have a car representing people with less transportation freedom. They analyzed the CEX with this new way of classifying transportation users and found that captive drivers carry the most transportation burden. The transportation expenditures of captive drivers average more than 16% of total household expenditures while the transportation expenditures of captive riders was only around 7% of total expenditures.
#
# ### 2.4 The Current Study
#
# Like many of the existing studies described, the current study improves our understanding of household spending patterns and transportation choices. It adds to the literature in three main ways: Dataset, Methodology, and Research Question.
#
# #### 2.4.1 Dataset
#
# Many studies seek to understand household transportation choices with time use diaries or travel surveys. This study, on the other hand, seeks to answer similar questions using expenditure data. Instead of using day to day activities to understand where and how a household is getting around, we use households’ weekly expenses to find underlying patterns that explain, and perhaps shape, their travel choices.
#
# Another important thing to note is that all of the reviewed transportation studies using the CEX were using data from before 2020. Since much has changed since the COVID19 pandemic, the 2024 data used in the current study will provide a more timely analysis.
#
# #### 2.4.2 Methodology
#
# The latent class analysis for the current study looks at unique exogenous and outcome variables. To perform the analysis, we created categories to reflect the type of expenditures made. We used these unique categories in the analysis. The exogenous and outcome variables we used in the analysis are listed below.
#
# - List of variables used in analysis
#
# #### 2.4.3 Research Question
#
# The purpose of the current study is to see how household budgets are structured around transportation decisions. We are going about it with the perspective that transportation expenditures help define a household. Looking at the data in this way will help us find trends that were perhaps missed in other studies on transportation decisions.
#
# ## 3 Data
#
# Data for the following analysis were obtained from the 2024 Consumer Expenditure Survey (CEX) Public Use Microdata (PUMD). The CEX is administered continuously by the Bureau of Labor Statistics (BLS). The data are organized by quarter and published each year. The CEX consists of two surveys: the Interview Survey, and the Diary Survey. Each survey has it’s own unique sample, so the households in one will not appear in the other. The Interview Survey tracks a household’s major and recurring expenditures by reviewing their expenses from the past three months, and the Diary Survey captures more routine household spending by recording in detail a households expenditure across a two-week span.
#
# Because we were interested in the day-to-day expenditures of households, this study uses data from the Diary Survey of the CEX. To gather this data, BLS personnel contact a sample of US households, record household demographic data, and explain how to fill out the weekly expenditure diary. After two consecutive weeks of reporting expenditures, the household is removed from the sample and replaced by a new household. The combination of household demographics and detailed expenditures available in the Diary Survey makes this data set ideal for the current study.
#
# <a href="#tbl-ce-files" class="quarto-xref">Table 2</a> shows the files in the PUMD that pertain to the Diary Survey. For this study, we specifically looked at the FMLD and the EXPD files from 2024 to get household[1] characteristics along with their detailed spending tables. In the 2024 data, there were a total of 6,334 households surveyed. To capture the most expenditures and keep consistency, we only kept households that had participated in the study for two consecutive weeks during the study period. We also excluded any households who had no recorded expenditures during the two survey weeks. After filtering out the 161 households with only one week of data and the 169 households with no expenditures, we were left with 6,004 households used in the analysis.
#
# [1] Note that “household” in this paper is synonymous with what the CEX often denotes as “Consumer Unit” (CU)

# %%
ce_files <- read.csv("data/tables/ce_data_files.csv")
names(ce_files) <- c("File Name","Description")

gt(ce_files)

# %%
ucc_codes <- read_excel("data/data_prep_input/ucc_categories.xlsx") |>
  filter(in_exp_file == 1)

expense_types <- unique(ucc_codes$ucc_code)
categories <- unique(ucc_codes$broad_category)

# %% [markdown]
# In the expenditures data, there were 410 unique types of expenditures recorded with each expenditure designated by a Universal Classification Code (UCC). We organized this into 7 categories as shown in <a href="#tbl-spending-categories" class="quarto-xref">Table 3</a> (for a more detailed breakdown of the expenditure categories, see [Appendix A](#sec-appendix-a)). Since this study focuses on transportation expenditures, we further split the transportation category into smaller categories based on mode. The specific UCC codes for each item in the transportation categories are listed in <a href="#tbl-transpo-categories" class="quarto-xref">Table 4</a>.

# %%
expense_categories <- read.csv("data/tables/ce_expense_categories.csv")

names(expense_categories) <- c("Category", "Types of Expenses")

gt(expense_categories)

# %%
transpo_cats <- ucc_codes |>
  filter(broad_category == "Transportation") |>
  select(ucc_code, `Code description`, category)

names(transpo_cats) <- c("UCC Code","Code Description","Transportation Category")

transpo_cats |> 
  gt(
    # rowname_col = "UCC Code",
     groupname_col = "Transportation Category",
     row_group_as_column = TRUE) |>
  row_group_order(c("Car Purchase",
                    "Car Maintenance",
                    "Car Fuel",
                    "Car Payment",
                    "Bus Travel",
                    "Train Travel",
                    "Taxi or Limo Travel",
                    "Bike or Scooter or other Single Rider Travel",
                    "Air Travel",
                    "Train Travel"
                    ))

# %% [markdown]
# The average spending in each of the major categories mentioned above is shown in <a href="#tbl-category-spending" class="quarto-xref">Table 5</a>. As seen in the table, there were four categories in which more than 75% of the sample had expenditures: food, house, mandatory, and transportation. The portion of the sample with food-related expenditures was just under 100 percent, and those with house-related expenditures was over 80 percent. This shows that practically no household went two weeks without purchasing food, and only a small portion of the households went two weeks without having a house-related expense. When including all the households in the sample, the average spending on transportation is approximately \$260, and that average increases to approximately \$325 when looking at only the households who had transportation expenditures.
#
# The average spending in each of the specific transportation categories is found in <a href="#tbl-transpo-spending" class="quarto-xref">Table 6</a>. Car fuel and car maintenance were the the expense categories that included the most households. The categories with the highest averages were car purchases, car payments, and ship travel, but these had relatively low numbers of households spending any money in the categories.
#
# ``` python
# grouped_exp |>
#   mutate(pct_zeros = avg_exp_zeros * 100 / sum(avg_exp_zeros),
#          pct_no_zeros = avg_exp_no_zeros * 100 / sum(avg_exp_no_zeros)) |>
#   arrange(desc(count)) |>
#   mutate(avg_exp_zeros = paste0("$",round(avg_exp_zeros, 2), " (",round(pct_zeros,2),"%)"),
#          avg_exp_no_zeros = paste0("$",round(avg_exp_no_zeros, 2), " (",round(pct_no_zeros,2),"%)"),
#          count_pct = paste0(count, " (",round(count * 100 / 6004,1),"% of sample)")) |>
#
#   select(`Spending Category` = broad_category,
#          `Average spending including all households` = avg_exp_zeros,
#          `Average spending for only households that spent some in this category` = avg_exp_no_zeros,
#          `Households with spending in this category` = count_pct) |>
#   gt()
# ```
#
# <div id="hkoyfgmifp" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>#hkoyfgmifp table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #hkoyfgmifp thead, #hkoyfgmifp tbody, #hkoyfgmifp tfoot, #hkoyfgmifp tr, #hkoyfgmifp td, #hkoyfgmifp th {
#   border-style: none;
# }
#
# #hkoyfgmifp p {
#   margin: 0;
#   padding: 0;
# }
#
# #hkoyfgmifp .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #hkoyfgmifp .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #hkoyfgmifp .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #hkoyfgmifp .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #hkoyfgmifp .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #hkoyfgmifp .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #hkoyfgmifp .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #hkoyfgmifp .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #hkoyfgmifp .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #hkoyfgmifp .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #hkoyfgmifp .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #hkoyfgmifp .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #hkoyfgmifp .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #hkoyfgmifp .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #hkoyfgmifp .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hkoyfgmifp .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #hkoyfgmifp .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #hkoyfgmifp .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #hkoyfgmifp .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hkoyfgmifp .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #hkoyfgmifp .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hkoyfgmifp .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #hkoyfgmifp .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hkoyfgmifp .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #hkoyfgmifp .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hkoyfgmifp .gt_left {
#   text-align: left;
# }
#
# #hkoyfgmifp .gt_center {
#   text-align: center;
# }
#
# #hkoyfgmifp .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #hkoyfgmifp .gt_font_normal {
#   font-weight: normal;
# }
#
# #hkoyfgmifp .gt_font_bold {
#   font-weight: bold;
# }
#
# #hkoyfgmifp .gt_font_italic {
#   font-style: italic;
# }
#
# #hkoyfgmifp .gt_super {
#   font-size: 65%;
# }
#
# #hkoyfgmifp .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #hkoyfgmifp .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #hkoyfgmifp .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #hkoyfgmifp .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #hkoyfgmifp .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #hkoyfgmifp .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #hkoyfgmifp .gt_indent_5 {
#   text-indent: 25px;
# }
#
# #hkoyfgmifp .katex-display {
#   display: inline-flex !important;
#   margin-bottom: 0.75em !important;
# }
#
# #hkoyfgmifp div.Reactable > div.rt-table > div.rt-thead > div.rt-tr.rt-tr-group-header > div.rt-th-group:after {
#   height: 0px !important;
# }
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
#   <thead>
#     <tr class="gt_col_headings">
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Spending-Category">Spending Category</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Average-spending-including-all-households">Average spending including all households</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Average-spending-for-only-households-that-spent-some-in-this-category">Average spending for only households that spent some in this category</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Households-with-spending-in-this-category">Households with spending in this category</th>
#     </tr>
#   </thead>
#   <tbody class="gt_table_body">
#     <tr><td headers="Spending Category" class="gt_row gt_left">Food</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$413.11 (21.24%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$414.35 (15.64%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">5986 (99.7% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">House Related</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$635.82 (32.69%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$755.03 (28.5%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">5056 (84.2% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Mandatory</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$260.83 (13.41%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$320.25 (12.09%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">4890 (81.4% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Transportation</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$260.08 (13.37%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$326.75 (12.33%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">4779 (79.6% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Leisure</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$170.28 (8.76%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$270.68 (10.22%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">3777 (62.9% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Other</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$187.12 (9.62%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$439.19 (16.58%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">2558 (42.6% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">School</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$17.69 (0.91%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$122.92 (4.64%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">864 (14.4% of sample)</td></tr>
#   </tbody>
#
# </table>
# </div>
#
# Table 5: Average Spending per Household in Each Category
#
# ``` python
# transpo_exp |>
#   mutate(pct_zeros = avg_exp_zeros * 100 / sum(avg_exp_zeros),
#          pct_no_zeros = avg_exp_no_zeros * 100 / sum(avg_exp_no_zeros)) |>
#   arrange(desc(count)) |>
#   mutate(avg_exp_zeros = paste0("$",round(avg_exp_zeros, 2), " (",round(pct_zeros,2),"%)"),
#          avg_exp_no_zeros = paste0("$",round(avg_exp_no_zeros, 2), " (",round(pct_no_zeros,2),"%)"),
#          count_pct = paste0(count, " (",round(count * 100 / 6004,1),"% of sample)")) |>
#
#   select(`Spending Category` = category,
#          `Average spending including all households` = avg_exp_zeros,
#          `Average spending for only households that spent some in this category` = avg_exp_no_zeros,
#          `Households with spending in this category` = count_pct) |>
#   gt()
# ```
#
# <div id="bqdrrltevq" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>#bqdrrltevq table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #bqdrrltevq thead, #bqdrrltevq tbody, #bqdrrltevq tfoot, #bqdrrltevq tr, #bqdrrltevq td, #bqdrrltevq th {
#   border-style: none;
# }
#
# #bqdrrltevq p {
#   margin: 0;
#   padding: 0;
# }
#
# #bqdrrltevq .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #bqdrrltevq .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #bqdrrltevq .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #bqdrrltevq .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #bqdrrltevq .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #bqdrrltevq .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #bqdrrltevq .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #bqdrrltevq .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #bqdrrltevq .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #bqdrrltevq .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #bqdrrltevq .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #bqdrrltevq .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #bqdrrltevq .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #bqdrrltevq .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #bqdrrltevq .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #bqdrrltevq .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #bqdrrltevq .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #bqdrrltevq .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #bqdrrltevq .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #bqdrrltevq .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #bqdrrltevq .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #bqdrrltevq .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #bqdrrltevq .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #bqdrrltevq .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #bqdrrltevq .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #bqdrrltevq .gt_left {
#   text-align: left;
# }
#
# #bqdrrltevq .gt_center {
#   text-align: center;
# }
#
# #bqdrrltevq .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #bqdrrltevq .gt_font_normal {
#   font-weight: normal;
# }
#
# #bqdrrltevq .gt_font_bold {
#   font-weight: bold;
# }
#
# #bqdrrltevq .gt_font_italic {
#   font-style: italic;
# }
#
# #bqdrrltevq .gt_super {
#   font-size: 65%;
# }
#
# #bqdrrltevq .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #bqdrrltevq .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #bqdrrltevq .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #bqdrrltevq .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #bqdrrltevq .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #bqdrrltevq .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #bqdrrltevq .gt_indent_5 {
#   text-indent: 25px;
# }
#
# #bqdrrltevq .katex-display {
#   display: inline-flex !important;
#   margin-bottom: 0.75em !important;
# }
#
# #bqdrrltevq div.Reactable > div.rt-table > div.rt-thead > div.rt-tr.rt-tr-group-header > div.rt-th-group:after {
#   height: 0px !important;
# }
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
#   <thead>
#     <tr class="gt_col_headings">
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Spending-Category">Spending Category</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Average-spending-including-all-households">Average spending including all households</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Average-spending-for-only-households-that-spent-some-in-this-category">Average spending for only households that spent some in this category</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Households-with-spending-in-this-category">Households with spending in this category</th>
#     </tr>
#   </thead>
#   <tbody class="gt_table_body">
#     <tr><td headers="Spending Category" class="gt_row gt_left">Car Fuel</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$78.86 (30.32%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$108 (1.13%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">4384 (73% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Car Maintenance</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$89.13 (34.27%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$283.01 (2.96%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">1891 (31.5% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Taxi or Limo Travel</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$2.54 (0.98%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$65.4 (0.68%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">233 (3.9% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Train Travel</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$1.56 (0.6%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$46.96 (0.49%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">200 (3.3% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Air Travel</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$16.76 (6.44%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$805.04 (8.43%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">125 (2.1% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Car Purchase</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$64.79 (24.91%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$3442.59 (36.03%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">113 (1.9% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Bike or Scooter or other Single Rider Travel</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$1.31 (0.5%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$137.59 (1.44%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">57 (0.9% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Bus Travel</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$0.17 (0.07%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$23.92 (0.25%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">43 (0.7% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Car Payment</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$4.37 (1.68%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$1141.45 (11.95%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">23 (0.4% of sample)</td></tr>
#     <tr><td headers="Spending Category" class="gt_row gt_left">Ship Travel</td>
# <td headers="Average spending including all households" class="gt_row gt_right">$0.58 (0.22%)</td>
# <td headers="Average spending for only households that spent some in this category" class="gt_row gt_right">$3500 (36.63%)</td>
# <td headers="Households with spending in this category" class="gt_row gt_left">1 (0% of sample)</td></tr>
#   </tbody>
#
# </table>
# </div>
#
# Table 6: Average Transportation Spending per Household in Each Category
#
# Most of the census data was found using the [Census Bereau Tables](https://data.census.gov/table). For city population, I used the census [city and town population totals](https://www.census.gov/data/tables/time-series/demo/popest/2020s-total-cities-and-towns.html) data.
#
# Highlights of <a href="#tbl-data-demographics" class="quarto-xref">Table 7</a>
#
# - CES had more people in the \<\$50K and less people in the \>\$200k. This is most likely because it is harder to get people in the higher income bracket to participate in the survey.
#
# - CES had less people in the younger age group and more in the older age group. This is most likely because we are comparing reference person age to just age in general. It makes sense that there are more 54+ people as reference person since the odds of older people owning a house is larger.
#
# - CES had more people. with bachelors degree or higher. I don’t know why, but could be connected to the city population. Maybe people with degrees are more likely to live in large cities over a million people.
#
# - The unmarried group is slightly lower in the CES survey. I’m not sure why, but I’m not sure it even needs to be talked about.
#
# - The biggest discrepancy is the city population. I think it says somewhere that the ces surveys are over-representative of large cities??
#
# ``` r
# demog_tbl <- read.csv("data/tables/ce_demog_vs_census.csv") |>
#   select(Variable, CES, Census, Group) |>
#   gt(groupname_col = "Group",
#      rowname_col = "Variable")
# ```
#
# Table 7: Demograhic distribution of the sample compared to census data
#
# Then there might still be some tables Katie wanted me to make. I will review those.
#
# 1.  Table with the buckets of transportation spending category splits.
# 2.  Same averages, but split them up by different household structures
#
# - Refer to R code on how to do this efficiently.
# - This is where we can start to tell the story that perhaps different household structures are spending their money in different transportation spending categories.
#
# ## 4 Results
#
# The analysis resulted in three latent classes which we named based on the household distribution of each class. The latent classes are described as follows.
#
# ### 4.1 Class 1: Car Spenders High (CH)
#
# This class mostly contains households that spend higher amounts of money on car-related travel. As shown in <a href="#tbl-model-classes" class="quarto-xref">Table 8</a>, the *CH* class has a much larger percent of households that spent over \$100 on both fuel and maintenance during the survey period. In those same categories, it had the smallest percent of households spending nothing in those categories. In terms of other modes of transportation, this class hardly had any households with expenses in the other transportation categories.
#
# ### 4.2 Class 2: Multimodal Spenders (MM)
#
# Unlike the *CH* category, the *MM* class contains a higher percentage of households that had spending in the transportation categories not involved with cars. For example, while less than 2% of households in the *CH* class spent any money on train travel, more than 50% of households in this class spend money on train travel with about 30% of households spending over \$20 on train travel.
#
# ### 4.3 Class 3: Car Spenders Low (CL)
#
# Similar to the *CH* class, the *CL* class had most expenditures in the car categories. However, there was a smaller percent of households with expenses in the higher ranges. For example, the *CH* class had over 45% households that spent over \$100 on fuel while the *CL* class had less than 15% exceeding \$100 in fuel. Like the *CH*, the *CL* class had very low percentages of households that spent money on modes besides cars. In fact, there were no households in this class that spent money on trains or buses.
#
# ``` python
# create_nice_probs_table(final_model,
#                         expense_variable_names,
#                         expense_level_names,
#                         lcm_data,
#                         c1_name = "Car Spenders High (CH)",
#                         c2_name = "Multimodal Spenders (MM)",
#                         c3_name = "Car Spenders Low (CL)")
# ```
#
# <div id="pahhxvtnwq" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>#pahhxvtnwq table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #pahhxvtnwq thead, #pahhxvtnwq tbody, #pahhxvtnwq tfoot, #pahhxvtnwq tr, #pahhxvtnwq td, #pahhxvtnwq th {
#   border-style: none;
# }
#
# #pahhxvtnwq p {
#   margin: 0;
#   padding: 0;
# }
#
# #pahhxvtnwq .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #pahhxvtnwq .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #pahhxvtnwq .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #pahhxvtnwq .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #pahhxvtnwq .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #pahhxvtnwq .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #pahhxvtnwq .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #pahhxvtnwq .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #pahhxvtnwq .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #pahhxvtnwq .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #pahhxvtnwq .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #pahhxvtnwq .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #pahhxvtnwq .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #pahhxvtnwq .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #pahhxvtnwq .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pahhxvtnwq .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #pahhxvtnwq .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #pahhxvtnwq .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #pahhxvtnwq .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pahhxvtnwq .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #pahhxvtnwq .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pahhxvtnwq .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #pahhxvtnwq .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pahhxvtnwq .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #pahhxvtnwq .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pahhxvtnwq .gt_left {
#   text-align: left;
# }
#
# #pahhxvtnwq .gt_center {
#   text-align: center;
# }
#
# #pahhxvtnwq .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #pahhxvtnwq .gt_font_normal {
#   font-weight: normal;
# }
#
# #pahhxvtnwq .gt_font_bold {
#   font-weight: bold;
# }
#
# #pahhxvtnwq .gt_font_italic {
#   font-style: italic;
# }
#
# #pahhxvtnwq .gt_super {
#   font-size: 65%;
# }
#
# #pahhxvtnwq .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #pahhxvtnwq .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #pahhxvtnwq .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #pahhxvtnwq .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #pahhxvtnwq .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #pahhxvtnwq .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #pahhxvtnwq .gt_indent_5 {
#   text-indent: 25px;
# }
#
# #pahhxvtnwq .katex-display {
#   display: inline-flex !important;
#   margin-bottom: 0.75em !important;
# }
#
# #pahhxvtnwq div.Reactable > div.rt-table > div.rt-thead > div.rt-tr.rt-tr-group-header > div.rt-th-group:after {
#   height: 0px !important;
# }
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
#   <thead>
#     <tr class="gt_col_headings">
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="a::stub"></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="class_1">Car Spenders High (CH)</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="class_2">Multimodal Spenders (MM)</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="class_3">Car Spenders Low (CL)</th>
#     </tr>
#   </thead>
#   <tbody class="gt_table_body">
#     <tr class="gt_group_heading_row">
#       <th colspan="4" class="gt_group_heading" scope="colgroup" id="Class Probablilty">Class Probablilty</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_1" scope="row" class="gt_row gt_left gt_stub"></th>
# <td headers="Class Probablilty stub_1_1 class_1" class="gt_row gt_right">43.47</td>
# <td headers="Class Probablilty stub_1_1 class_2" class="gt_row gt_right">4.29</td>
# <td headers="Class Probablilty stub_1_1 class_3" class="gt_row gt_right">52.24</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="4" class="gt_group_heading" scope="colgroup" id="Car Fuel Expense">Car Fuel Expense</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_2" scope="row" class="gt_row gt_left gt_stub">None</th>
# <td headers="Car Fuel Expense stub_1_2 class_1" class="gt_row gt_right">8.30</td>
# <td headers="Car Fuel Expense stub_1_2 class_2" class="gt_row gt_right">49.10</td>
# <td headers="Car Fuel Expense stub_1_2 class_3" class="gt_row gt_right">40.72</td></tr>
#     <tr><th id="stub_1_3" scope="row" class="gt_row gt_left gt_stub">$0.00 - $50.00</th>
# <td headers="Car Fuel Expense stub_1_3 class_1" class="gt_row gt_right">16.20</td>
# <td headers="Car Fuel Expense stub_1_3 class_2" class="gt_row gt_right">19.28</td>
# <td headers="Car Fuel Expense stub_1_3 class_3" class="gt_row gt_right">21.60</td></tr>
#     <tr><th id="stub_1_4" scope="row" class="gt_row gt_left gt_stub">$50.00 - $100.00</th>
# <td headers="Car Fuel Expense stub_1_4 class_1" class="gt_row gt_right">26.94</td>
# <td headers="Car Fuel Expense stub_1_4 class_2" class="gt_row gt_right">17.12</td>
# <td headers="Car Fuel Expense stub_1_4 class_3" class="gt_row gt_right">23.08</td></tr>
#     <tr><th id="stub_1_5" scope="row" class="gt_row gt_left gt_stub">$100.00 +</th>
# <td headers="Car Fuel Expense stub_1_5 class_1" class="gt_row gt_right">48.56</td>
# <td headers="Car Fuel Expense stub_1_5 class_2" class="gt_row gt_right">14.50</td>
# <td headers="Car Fuel Expense stub_1_5 class_3" class="gt_row gt_right">14.61</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="4" class="gt_group_heading" scope="colgroup" id="Car Maintenance Expense">Car Maintenance Expense</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_6" scope="row" class="gt_row gt_left gt_stub">None</th>
# <td headers="Car Maintenance Expense stub_1_6 class_1" class="gt_row gt_right">41.87</td>
# <td headers="Car Maintenance Expense stub_1_6 class_2" class="gt_row gt_right">83.44</td>
# <td headers="Car Maintenance Expense stub_1_6 class_3" class="gt_row gt_right">89.45</td></tr>
#     <tr><th id="stub_1_7" scope="row" class="gt_row gt_left gt_stub">$50.00 - $100.00</th>
# <td headers="Car Maintenance Expense stub_1_7 class_1" class="gt_row gt_right">21.49</td>
# <td headers="Car Maintenance Expense stub_1_7 class_2" class="gt_row gt_right">11.28</td>
# <td headers="Car Maintenance Expense stub_1_7 class_3" class="gt_row gt_right">6.98</td></tr>
#     <tr><th id="stub_1_8" scope="row" class="gt_row gt_left gt_stub">$100.00 +</th>
# <td headers="Car Maintenance Expense stub_1_8 class_1" class="gt_row gt_right">36.64</td>
# <td headers="Car Maintenance Expense stub_1_8 class_2" class="gt_row gt_right">5.29</td>
# <td headers="Car Maintenance Expense stub_1_8 class_3" class="gt_row gt_right">3.57</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="4" class="gt_group_heading" scope="colgroup" id="Taxi Travel Expense">Taxi Travel Expense</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_9" scope="row" class="gt_row gt_left gt_stub">None</th>
# <td headers="Taxi Travel Expense stub_1_9 class_1" class="gt_row gt_right">96.33</td>
# <td headers="Taxi Travel Expense stub_1_9 class_2" class="gt_row gt_right">54.44</td>
# <td headers="Taxi Travel Expense stub_1_9 class_3" class="gt_row gt_right">99.37</td></tr>
#     <tr><th id="stub_1_10" scope="row" class="gt_row gt_left gt_stub">$0.00 - $20.00</th>
# <td headers="Taxi Travel Expense stub_1_10 class_1" class="gt_row gt_right">1.42</td>
# <td headers="Taxi Travel Expense stub_1_10 class_2" class="gt_row gt_right">9.10</td>
# <td headers="Taxi Travel Expense stub_1_10 class_3" class="gt_row gt_right">0.08</td></tr>
#     <tr><th id="stub_1_11" scope="row" class="gt_row gt_left gt_stub">$20.00 - $50.00</th>
# <td headers="Taxi Travel Expense stub_1_11 class_1" class="gt_row gt_right">1.36</td>
# <td headers="Taxi Travel Expense stub_1_11 class_2" class="gt_row gt_right">15.48</td>
# <td headers="Taxi Travel Expense stub_1_11 class_3" class="gt_row gt_right">0.08</td></tr>
#     <tr><th id="stub_1_12" scope="row" class="gt_row gt_left gt_stub">$50.00 +</th>
# <td headers="Taxi Travel Expense stub_1_12 class_1" class="gt_row gt_right">0.89</td>
# <td headers="Taxi Travel Expense stub_1_12 class_2" class="gt_row gt_right">20.97</td>
# <td headers="Taxi Travel Expense stub_1_12 class_3" class="gt_row gt_right">0.47</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="4" class="gt_group_heading" scope="colgroup" id="Bus Travel Expense">Bus Travel Expense</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_13" scope="row" class="gt_row gt_left gt_stub">None</th>
# <td headers="Bus Travel Expense stub_1_13 class_1" class="gt_row gt_right">99.81</td>
# <td headers="Bus Travel Expense stub_1_13 class_2" class="gt_row gt_right">85.28</td>
# <td headers="Bus Travel Expense stub_1_13 class_3" class="gt_row gt_right">100.00</td></tr>
#     <tr><th id="stub_1_14" scope="row" class="gt_row gt_left gt_stub">Any</th>
# <td headers="Bus Travel Expense stub_1_14 class_1" class="gt_row gt_right">0.19</td>
# <td headers="Bus Travel Expense stub_1_14 class_2" class="gt_row gt_right">14.72</td>
# <td headers="Bus Travel Expense stub_1_14 class_3" class="gt_row gt_right">0.00</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="4" class="gt_group_heading" scope="colgroup" id="Train Travel Expense">Train Travel Expense</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_15" scope="row" class="gt_row gt_left gt_stub">None</th>
# <td headers="Train Travel Expense stub_1_15 class_1" class="gt_row gt_right">98.07</td>
# <td headers="Train Travel Expense stub_1_15 class_2" class="gt_row gt_right">41.96</td>
# <td headers="Train Travel Expense stub_1_15 class_3" class="gt_row gt_right">100.00</td></tr>
#     <tr><th id="stub_1_16" scope="row" class="gt_row gt_left gt_stub">$0.00 - $20.00</th>
# <td headers="Train Travel Expense stub_1_16 class_1" class="gt_row gt_right">1.37</td>
# <td headers="Train Travel Expense stub_1_16 class_2" class="gt_row gt_right">27.61</td>
# <td headers="Train Travel Expense stub_1_16 class_3" class="gt_row gt_right">0.00</td></tr>
#     <tr><th id="stub_1_17" scope="row" class="gt_row gt_left gt_stub">$20.00 +</th>
# <td headers="Train Travel Expense stub_1_17 class_1" class="gt_row gt_right">0.56</td>
# <td headers="Train Travel Expense stub_1_17 class_2" class="gt_row gt_right">30.43</td>
# <td headers="Train Travel Expense stub_1_17 class_3" class="gt_row gt_right">0.00</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="4" class="gt_group_heading" scope="colgroup" id="Air Travel Expense">Air Travel Expense</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_18" scope="row" class="gt_row gt_left gt_stub">None</th>
# <td headers="Air Travel Expense stub_1_18 class_1" class="gt_row gt_right">96.62</td>
# <td headers="Air Travel Expense stub_1_18 class_2" class="gt_row gt_right">88.76</td>
# <td headers="Air Travel Expense stub_1_18 class_3" class="gt_row gt_right">99.75</td></tr>
#     <tr><th id="stub_1_19" scope="row" class="gt_row gt_left gt_stub">$0.00 - $500.00</th>
# <td headers="Air Travel Expense stub_1_19 class_1" class="gt_row gt_right">1.94</td>
# <td headers="Air Travel Expense stub_1_19 class_2" class="gt_row gt_right">9.26</td>
# <td headers="Air Travel Expense stub_1_19 class_3" class="gt_row gt_right">0.08</td></tr>
#     <tr><th id="stub_1_20" scope="row" class="gt_row gt_left gt_stub">$500.00 +</th>
# <td headers="Air Travel Expense stub_1_20 class_1" class="gt_row gt_right">1.44</td>
# <td headers="Air Travel Expense stub_1_20 class_2" class="gt_row gt_right">1.99</td>
# <td headers="Air Travel Expense stub_1_20 class_3" class="gt_row gt_right">0.17</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="4" class="gt_group_heading" scope="colgroup" id="Microtransit Travel Expense">Microtransit Travel Expense</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_21" scope="row" class="gt_row gt_left gt_stub">None</th>
# <td headers="Microtransit Travel Expense stub_1_21 class_1" class="gt_row gt_right">98.28</td>
# <td headers="Microtransit Travel Expense stub_1_21 class_2" class="gt_row gt_right">96.62</td>
# <td headers="Microtransit Travel Expense stub_1_21 class_3" class="gt_row gt_right">99.89</td></tr>
#     <tr><th id="stub_1_22" scope="row" class="gt_row gt_left gt_stub">Any</th>
# <td headers="Microtransit Travel Expense stub_1_22 class_1" class="gt_row gt_right">1.72</td>
# <td headers="Microtransit Travel Expense stub_1_22 class_2" class="gt_row gt_right">3.38</td>
# <td headers="Microtransit Travel Expense stub_1_22 class_3" class="gt_row gt_right">0.11</td></tr>
#   </tbody>
#
# </table>
# </div>
#
# Table 8: Class Distribution of Model
#
# <a href="#tbl-model-coeff" class="quarto-xref">Table 9</a> shows the regression results of the latent class model. As seen in the table, most of the model coefficients are statistically significant. The following sections discuss the findings in more detail.
#
# ``` python
# create_nice_coeff_tbl(model_df,
#                       exog_name_key,
#                       highlighted = TRUE,
#                       highlight_color = "#FF820050",
#                       t_threshold = 1.4,
#                       only_significant = FALSE,
#                       two_vs_one_name = "MM vs. CH",
#                       three_vs_one_name = "CL vs. CH")
# ```
#
# <div id="rkhvkvvxtr" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>#rkhvkvvxtr table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #rkhvkvvxtr thead, #rkhvkvvxtr tbody, #rkhvkvvxtr tfoot, #rkhvkvvxtr tr, #rkhvkvvxtr td, #rkhvkvvxtr th {
#   border-style: none;
# }
#
# #rkhvkvvxtr p {
#   margin: 0;
#   padding: 0;
# }
#
# #rkhvkvvxtr .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #rkhvkvvxtr .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #rkhvkvvxtr .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #rkhvkvvxtr .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #rkhvkvvxtr .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #rkhvkvvxtr .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #rkhvkvvxtr .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #rkhvkvvxtr .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #rkhvkvvxtr .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #rkhvkvvxtr .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #rkhvkvvxtr .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #rkhvkvvxtr .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #rkhvkvvxtr .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #rkhvkvvxtr .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #rkhvkvvxtr .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #rkhvkvvxtr .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #rkhvkvvxtr .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #rkhvkvvxtr .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #rkhvkvvxtr .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #rkhvkvvxtr .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #rkhvkvvxtr .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #rkhvkvvxtr .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #rkhvkvvxtr .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #rkhvkvvxtr .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #rkhvkvvxtr .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #rkhvkvvxtr .gt_left {
#   text-align: left;
# }
#
# #rkhvkvvxtr .gt_center {
#   text-align: center;
# }
#
# #rkhvkvvxtr .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #rkhvkvvxtr .gt_font_normal {
#   font-weight: normal;
# }
#
# #rkhvkvvxtr .gt_font_bold {
#   font-weight: bold;
# }
#
# #rkhvkvvxtr .gt_font_italic {
#   font-style: italic;
# }
#
# #rkhvkvvxtr .gt_super {
#   font-size: 65%;
# }
#
# #rkhvkvvxtr .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #rkhvkvvxtr .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #rkhvkvvxtr .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #rkhvkvvxtr .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #rkhvkvvxtr .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #rkhvkvvxtr .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #rkhvkvvxtr .gt_indent_5 {
#   text-indent: 25px;
# }
#
# #rkhvkvvxtr .katex-display {
#   display: inline-flex !important;
#   margin-bottom: 0.75em !important;
# }
#
# #rkhvkvvxtr div.Reactable > div.rt-table > div.rt-thead > div.rt-tr.rt-tr-group-header > div.rt-th-group:after {
#   height: 0px !important;
# }
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
#   <thead>
#     <tr class="gt_col_headings">
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="a::stub"></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="coeff_1">MM vs. CH</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="coeff_2">CL vs. CH</th>
#     </tr>
#   </thead>
#   <tbody class="gt_table_body">
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Intercept">Intercept</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_1" scope="row" class="gt_row gt_left gt_stub">Intercept</th>
# <td headers="Intercept stub_1_1 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.775 (-2.144)</td>
# <td headers="Intercept stub_1_1 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">5.503 (9.347)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Income (more than $50,000)">Income (more than $50,000)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_2" scope="row" class="gt_row gt_left gt_stub">$50,000 or less</th>
# <td headers="Income (more than $50,000) stub_1_2 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">0.395 (1.684)</td>
# <td headers="Income (more than $50,000) stub_1_2 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">0.583 (3.992)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Reference Age (55 or older)">Reference Age (55 or older)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_3" scope="row" class="gt_row gt_left gt_stub">18 - 34</th>
# <td headers="Reference Age (55 or older) stub_1_3 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">1.086 (4.193)</td>
# <td headers="Reference Age (55 or older) stub_1_3 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.32 (-1.618)</td></tr>
#     <tr><th id="stub_1_4" scope="row" class="gt_row gt_left gt_stub">35 - 44</th>
# <td headers="Reference Age (55 or older) stub_1_4 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">0.462 (1.484)</td>
# <td headers="Reference Age (55 or older) stub_1_4 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.433 (-2.04)</td></tr>
#     <tr><th id="stub_1_5" scope="row" class="gt_row gt_left gt_stub">45 - 54</th>
# <td headers="Reference Age (55 or older) stub_1_5 coeff_1" class="gt_row gt_center">0.144 (0.461)</td>
# <td headers="Reference Age (55 or older) stub_1_5 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.494 (-2.4)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Region (not Northeast)">Region (not Northeast)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_6" scope="row" class="gt_row gt_left gt_stub">Northeast</th>
# <td headers="Region (not Northeast) stub_1_6 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">1.684 (7.825)</td>
# <td headers="Region (not Northeast) stub_1_6 coeff_2" class="gt_row gt_center">0.2 (1.149)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Education (No college degree)">Education (No college degree)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_7" scope="row" class="gt_row gt_left gt_stub">Masters or above</th>
# <td headers="Education (No college degree) stub_1_7 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">0.976 (3.435)</td>
# <td headers="Education (No college degree) stub_1_7 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">0.337 (1.86)</td></tr>
#     <tr><th id="stub_1_8" scope="row" class="gt_row gt_left gt_stub">Bachelors</th>
# <td headers="Education (No college degree) stub_1_8 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">0.615 (2.226)</td>
# <td headers="Education (No college degree) stub_1_8 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.284 (-1.816)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Household Structure (Single without children)">Household Structure (Single without children)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_9" scope="row" class="gt_row gt_left gt_stub">Single with children</th>
# <td headers="Household Structure (Single without children) stub_1_9 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.755 (-3.056)</td>
# <td headers="Household Structure (Single without children) stub_1_9 coeff_2" class="gt_row gt_center">-0.34 (-1.21)</td></tr>
#     <tr><th id="stub_1_10" scope="row" class="gt_row gt_left gt_stub">Married without children</th>
# <td headers="Household Structure (Single without children) stub_1_10 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.014 (-3.883)</td>
# <td headers="Household Structure (Single without children) stub_1_10 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.494 (-3.047)</td></tr>
#     <tr><th id="stub_1_11" scope="row" class="gt_row gt_left gt_stub">Married with children</th>
# <td headers="Household Structure (Single without children) stub_1_11 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.381 (-3.952)</td>
# <td headers="Household Structure (Single without children) stub_1_11 coeff_2" class="gt_row gt_center">0.179 (0.828)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Population Size (Below 1 million)">Population Size (Below 1 million)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_12" scope="row" class="gt_row gt_left gt_stub">Above 1 million</th>
# <td headers="Population Size (Below 1 million) stub_1_12 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">1.785 (5.255)</td>
# <td headers="Population Size (Below 1 million) stub_1_12 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">0.318 (2.333)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Mandatory Expenses (none)">Mandatory Expenses (none)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_13" scope="row" class="gt_row gt_left gt_stub">$0.01 - $200</th>
# <td headers="Mandatory Expenses (none) stub_1_13 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.576 (-1.641)</td>
# <td headers="Mandatory Expenses (none) stub_1_13 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.826 (-3.622)</td></tr>
#     <tr><th id="stub_1_14" scope="row" class="gt_row gt_left gt_stub">$200.01 - $500</th>
# <td headers="Mandatory Expenses (none) stub_1_14 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.633 (-1.659)</td>
# <td headers="Mandatory Expenses (none) stub_1_14 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.54 (-6.002)</td></tr>
#     <tr><th id="stub_1_15" scope="row" class="gt_row gt_left gt_stub">&gt; $500</th>
# <td headers="Mandatory Expenses (none) stub_1_15 coeff_1" class="gt_row gt_center">-0.374 (-0.917)</td>
# <td headers="Mandatory Expenses (none) stub_1_15 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-2.086 (-6.555)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="House Expenses (none)">House Expenses (none)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_16" scope="row" class="gt_row gt_left gt_stub">$0.01 - $200</th>
# <td headers="House Expenses (none) stub_1_16 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.534 (-3.089)</td>
# <td headers="House Expenses (none) stub_1_16 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.912 (-4.656)</td></tr>
#     <tr><th id="stub_1_17" scope="row" class="gt_row gt_left gt_stub">$200.01 - $500</th>
# <td headers="House Expenses (none) stub_1_17 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.708 (-3.191)</td>
# <td headers="House Expenses (none) stub_1_17 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-2.52 (-5.882)</td></tr>
#     <tr><th id="stub_1_18" scope="row" class="gt_row gt_left gt_stub">&gt; $500</th>
# <td headers="House Expenses (none) stub_1_18 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-2.237 (-4.289)</td>
# <td headers="House Expenses (none) stub_1_18 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-3.144 (-7.312)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Food Expenses (&amp;lt;$100)">Food Expenses (&lt;$100)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_19" scope="row" class="gt_row gt_left gt_stub">$100.01 - $500</th>
# <td headers="Food Expenses (<$100) stub_1_19 coeff_1" class="gt_row gt_center">-0.234 (-0.462)</td>
# <td headers="Food Expenses (<$100) stub_1_19 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.093 (-4.116)</td></tr>
#     <tr><th id="stub_1_20" scope="row" class="gt_row gt_left gt_stub">&gt;$500</th>
# <td headers="Food Expenses (<$100) stub_1_20 coeff_1" class="gt_row gt_center">-0.085 (-0.159)</td>
# <td headers="Food Expenses (<$100) stub_1_20 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-2.263 (-7.346)</td></tr>
#     <tr class="gt_group_heading_row">
#       <th colspan="3" class="gt_group_heading" scope="colgroup" id="Leisure Expenses (none)">Leisure Expenses (none)</th>
#     </tr>
#     <tr class="gt_row_group_first"><th id="stub_1_21" scope="row" class="gt_row gt_left gt_stub">$0.01 - $100</th>
# <td headers="Leisure Expenses (none) stub_1_21 coeff_1" class="gt_row gt_center">-0.296 (-0.959)</td>
# <td headers="Leisure Expenses (none) stub_1_21 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.897 (-5.176)</td></tr>
#     <tr><th id="stub_1_22" scope="row" class="gt_row gt_left gt_stub">&gt;$100</th>
# <td headers="Leisure Expenses (none) stub_1_22 coeff_1" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-0.498 (-1.68)</td>
# <td headers="Leisure Expenses (none) stub_1_22 coeff_2" class="gt_row gt_center" style="background-color: rgba(255,130,0,0.31); font-weight: bold;">-1.678 (-9.671)</td></tr>
#   </tbody>
#   <tfoot>
#     <tr class="gt_footnotes">
#       <td class="gt_footnote" colspan="3"> Statistically significant cells are highlighted</td>
#     </tr>
#   </tfoot>
# </table>
# </div>
#
# Table 9: Regression Results of Model
#
# ### 4.4 Household Make-up
#
# Compared to single people with no children, both households with children and households with a married couple are more likely to be in the CH class than in the MM class. This makes sense to see that households with more people are more likely to have their transportation expenses oriented around cars because heavier travel demands and the balance of multiple schedules increases the convenience of a car. This also aligns with the study by Thakuriah and Liao ([2005](#ref-thakuriah_analysis_2005)) which found vehicle expenses to be connected to the number of people in the household. Comparing the MM class to the CH class, the coefficient for “married without children” households has the smallest absolute value, this shows that having children in the household has a stronger effect on being in the CH class than having a married couple in the household does. This “married without children” variable is also the only one with a statistically significant coefficient when comparing the CL class to the CH class. This means that “married without children” households are more likely to be in the CH class than the CL class compared to “single” households. This also makes sense because married couples will most likely have more trips than a single person, and this will equate to more transportation spending.
#
# ### 4.5 Location
#
# Compared to other areas of the country, households in the northeast are more likely to be in the MM class than in in the CH class. This also makes sense because the northeast is relatively dense and has some of the longest history of transit use. Additionally, household in cities of more than one million people are less likely to be in the CH class compared to the other classes. This makes sense for similar reason as the region findings.
#
# - (There is probably a study on how the more populous areas have less car use.)
#
# The findings from the coefficients for both the region and the city size support findings in other transportation studies. Deka ([2015](#ref-deka_relationship_2015)) found transportation expenditures to be higher for those living in single-family, detached homes and lower for those living in older homes. Mattson and Peterson ([2019](#ref-mattson_relationships_2019)) and Mattson ([2020](#ref-mattson_relationships_2020)) also found a positive correlation between transportation expenses and living in a single family home. The density and history of the northeast region of the united states, and of most large cities, makes it more likely to have old homes and higher concentrations of multifamily homes. These places will be more likely to spend less on transportation and use modes other than cars.
#
# ### 4.6 Other Household Demographics
#
# Compared to people that are 55 years old or older, households with a reference person younger than 55 are more likely to be in the MM class as opposed to the CH class. Additionally, households with a reference person younger than 55 are more likely to be in the CH class as apposed to the CL class. It makes sense that people older than 55 are more likely to use cars, but, compared to everyone who spends money on cars, they are more likely to be small spenders because they don’t have as many trips.
#
# - (There is probably a study on how younger adults are more likely to take transit or active transportation)
#
# Compared to those making more than \$50,000 a year, those making less than \$50,000 a year are less likely to be in CH as apposed to both MM and CL. This makes sense and aligns with previous studies. Household with less income will most likely spend less on transportation ([Molloy et al. 2024](#ref-molloy_new_2024); [Sener et al. 2008](#ref-sener_analysis_2008)).
#
# Compared with those who don’t have a college degree, those with a degree are more likely to be in the MM class as opposed to the CH class. Compared with those who don’t have a college education, those with bachelors degree are more likely to be in the CH class as opposed to the CL class while those with a doctorate degree are more likely to be in the CL compared to the CH class. This could be because people with doctorates have more opportunities to work from home or more flexibility to live close to their work.
#
# ### 4.7 Household Expenditures
#
# Compared to those who spend nothing in mandatory spending, those who have mandatory expenses, are more likely to be in the CH class as opposed to the MM class. Compared to those who spend nothing in mandatory spending, those who have mandatory expenses, are more likely to be in the CH class as opposed to the CL class. The different coefficient values show that people spending over \$500 on mandatory spending are more likely to be in CH class compared to the households spending less on mandatory things.
#
# Compared with households who have no house-related expenses, households with house related expenses are more likely to be in the CH class. It also looks like, in both comparisons, that the higher people are paying on house-related expenses, the more likely they are to be in the CH class compared to those without house-related expenses.
#
# Compared to those households who spend less than \$100 on leisure, households who spend more than \$100 are more likely to be in the CH class. It makes sense that spending on Leisure activities would be positively correlated with transportation spending since the more spend on leisure could very likely indicate more trips made.
#
# The coefficients related to household spending tend to increase in absolute value as the spending ranges increase. It is reasonable to see the probability of being in the high spending transportation class increase as other household expenses increase. More household expenses often mean more trips are being made.
#
# ### 4.8 Some More Results
#
# I think <a href="#tbl-model-covarpcts" class="quarto-xref">Table 10</a> is showing what percent of households fall into each category in each class. But I just put this in here to look at it. It won’t be in the final paper.
#
# ``` python
# covariates <- c("income_less_50k",
#                 "age_ref_35_to_44", "age_ref_45_to_54","age_ref_18_to_34",
#                 "region_northeast",
#                 "edu_masters_doctorate","edu_bachelors",
#                 "single_kids",
#                 "married_no_kids", "married_kids",
#                 "pop_more_1_mil",
#                 "mandatory2", "mandatory3" ,"mandatory4",
#                 "house2" ,"house3" , "house4",
#                 "food2" , "food3",
#                 "leisure2" , "leisure3")
#
# create_nice_covariate_tbl(final_model, lcm_data, covariates)
# ```
#
# <div id="nsadjuwykj" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>#nsadjuwykj table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #nsadjuwykj thead, #nsadjuwykj tbody, #nsadjuwykj tfoot, #nsadjuwykj tr, #nsadjuwykj td, #nsadjuwykj th {
#   border-style: none;
# }
#
# #nsadjuwykj p {
#   margin: 0;
#   padding: 0;
# }
#
# #nsadjuwykj .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #nsadjuwykj .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #nsadjuwykj .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #nsadjuwykj .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #nsadjuwykj .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #nsadjuwykj .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #nsadjuwykj .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #nsadjuwykj .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #nsadjuwykj .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #nsadjuwykj .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #nsadjuwykj .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #nsadjuwykj .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #nsadjuwykj .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #nsadjuwykj .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #nsadjuwykj .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #nsadjuwykj .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #nsadjuwykj .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #nsadjuwykj .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #nsadjuwykj .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #nsadjuwykj .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #nsadjuwykj .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #nsadjuwykj .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #nsadjuwykj .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #nsadjuwykj .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #nsadjuwykj .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #nsadjuwykj .gt_left {
#   text-align: left;
# }
#
# #nsadjuwykj .gt_center {
#   text-align: center;
# }
#
# #nsadjuwykj .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #nsadjuwykj .gt_font_normal {
#   font-weight: normal;
# }
#
# #nsadjuwykj .gt_font_bold {
#   font-weight: bold;
# }
#
# #nsadjuwykj .gt_font_italic {
#   font-style: italic;
# }
#
# #nsadjuwykj .gt_super {
#   font-size: 65%;
# }
#
# #nsadjuwykj .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #nsadjuwykj .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #nsadjuwykj .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #nsadjuwykj .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #nsadjuwykj .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #nsadjuwykj .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #nsadjuwykj .gt_indent_5 {
#   text-indent: 25px;
# }
#
# #nsadjuwykj .katex-display {
#   display: inline-flex !important;
#   margin-bottom: 0.75em !important;
# }
#
# #nsadjuwykj div.Reactable > div.rt-table > div.rt-thead > div.rt-tr.rt-tr-group-header > div.rt-th-group:after {
#   height: 0px !important;
# }
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
#   <thead>
#     <tr class="gt_col_headings">
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="2" scope="colgroup" id="a::stub"></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Class.1.mean">Class.1.mean</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Class.2.mean">Class.2.mean</th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Class.3.mean">Class.3.mean</th>
#     </tr>
#   </thead>
#   <tbody class="gt_table_body">
#     <tr class="gt_row_group_first"><td headers="Income (more than $50,000) stub_2_1 stub_1" rowspan="1" class="gt_row gt_left gt_stub_row_group">Income (more than $50,000)</td>
# <th id="stub_2_1" scope="row" class="gt_row gt_left gt_stub">$50,000 or less</th>
# <td headers="Income (more than $50,000) stub_2_1 Class.1.mean" class="gt_row gt_right">0.274</td>
# <td headers="Income (more than $50,000) stub_2_1 Class.2.mean" class="gt_row gt_right">0.316</td>
# <td headers="Income (more than $50,000) stub_2_1 Class.3.mean" class="gt_row gt_right">0.557</td></tr>
#     <tr class="gt_row_group_first"><td headers="Reference Age (55 or older) stub_2_2 stub_1" rowspan="3" class="gt_row gt_left gt_stub_row_group">Reference Age (55 or older)</td>
# <th id="stub_2_2" scope="row" class="gt_row gt_left gt_stub">35 - 44</th>
# <td headers="Reference Age (55 or older) stub_2_2 Class.1.mean" class="gt_row gt_right">0.199</td>
# <td headers="Reference Age (55 or older) stub_2_2 Class.2.mean" class="gt_row gt_right">0.183</td>
# <td headers="Reference Age (55 or older) stub_2_2 Class.3.mean" class="gt_row gt_right">0.146</td></tr>
#     <tr><th id="stub_2_3" scope="row" class="gt_row gt_left gt_stub">45 - 54</th>
# <td headers="Reference Age (55 or older) stub_2_3 Class.1.mean" class="gt_row gt_right">0.186</td>
# <td headers="Reference Age (55 or older) stub_2_3 Class.2.mean" class="gt_row gt_right">0.140</td>
# <td headers="Reference Age (55 or older) stub_2_3 Class.3.mean" class="gt_row gt_right">0.130</td></tr>
#     <tr><th id="stub_2_4" scope="row" class="gt_row gt_left gt_stub">18 - 34</th>
# <td headers="Reference Age (55 or older) stub_2_4 Class.1.mean" class="gt_row gt_right">0.145</td>
# <td headers="Reference Age (55 or older) stub_2_4 Class.2.mean" class="gt_row gt_right">0.338</td>
# <td headers="Reference Age (55 or older) stub_2_4 Class.3.mean" class="gt_row gt_right">0.160</td></tr>
#     <tr class="gt_row_group_first"><td headers="Region (not Northeast) stub_2_5 stub_1" rowspan="1" class="gt_row gt_left gt_stub_row_group">Region (not Northeast)</td>
# <th id="stub_2_5" scope="row" class="gt_row gt_left gt_stub">Northeast</th>
# <td headers="Region (not Northeast) stub_2_5 Class.1.mean" class="gt_row gt_right">0.141</td>
# <td headers="Region (not Northeast) stub_2_5 Class.2.mean" class="gt_row gt_right">0.522</td>
# <td headers="Region (not Northeast) stub_2_5 Class.3.mean" class="gt_row gt_right">0.156</td></tr>
#     <tr class="gt_row_group_first"><td headers="Education (No college degree) stub_2_6 stub_1" rowspan="2" class="gt_row gt_left gt_stub_row_group">Education (No college degree)</td>
# <th id="stub_2_6" scope="row" class="gt_row gt_left gt_stub">Masters or above</th>
# <td headers="Education (No college degree) stub_2_6 Class.1.mean" class="gt_row gt_right">0.267</td>
# <td headers="Education (No college degree) stub_2_6 Class.2.mean" class="gt_row gt_right">0.363</td>
# <td headers="Education (No college degree) stub_2_6 Class.3.mean" class="gt_row gt_right">0.185</td></tr>
#     <tr><th id="stub_2_7" scope="row" class="gt_row gt_left gt_stub">Bachelors</th>
# <td headers="Education (No college degree) stub_2_7 Class.1.mean" class="gt_row gt_right">0.334</td>
# <td headers="Education (No college degree) stub_2_7 Class.2.mean" class="gt_row gt_right">0.411</td>
# <td headers="Education (No college degree) stub_2_7 Class.3.mean" class="gt_row gt_right">0.247</td></tr>
#     <tr class="gt_row_group_first"><td headers="Household Structure (Single without children) stub_2_8 stub_1" rowspan="3" class="gt_row gt_left gt_stub_row_group">Household Structure (Single without children)</td>
# <th id="stub_2_8" scope="row" class="gt_row gt_left gt_stub">Single with children</th>
# <td headers="Household Structure (Single without children) stub_2_8 Class.1.mean" class="gt_row gt_right">0.066</td>
# <td headers="Household Structure (Single without children) stub_2_8 Class.2.mean" class="gt_row gt_right">0.027</td>
# <td headers="Household Structure (Single without children) stub_2_8 Class.3.mean" class="gt_row gt_right">0.062</td></tr>
#     <tr><th id="stub_2_9" scope="row" class="gt_row gt_left gt_stub">Married without children</th>
# <td headers="Household Structure (Single without children) stub_2_9 Class.1.mean" class="gt_row gt_right">0.426</td>
# <td headers="Household Structure (Single without children) stub_2_9 Class.2.mean" class="gt_row gt_right">0.269</td>
# <td headers="Household Structure (Single without children) stub_2_9 Class.3.mean" class="gt_row gt_right">0.292</td></tr>
#     <tr><th id="stub_2_10" scope="row" class="gt_row gt_left gt_stub">Married with children</th>
# <td headers="Household Structure (Single without children) stub_2_10 Class.1.mean" class="gt_row gt_right">0.232</td>
# <td headers="Household Structure (Single without children) stub_2_10 Class.2.mean" class="gt_row gt_right">0.132</td>
# <td headers="Household Structure (Single without children) stub_2_10 Class.3.mean" class="gt_row gt_right">0.142</td></tr>
#     <tr class="gt_row_group_first"><td headers="Population Size (Below 1 million) stub_2_11 stub_1" rowspan="1" class="gt_row gt_left gt_stub_row_group">Population Size (Below 1 million)</td>
# <th id="stub_2_11" scope="row" class="gt_row gt_left gt_stub">Above 1 million</th>
# <td headers="Population Size (Below 1 million) stub_2_11 Class.1.mean" class="gt_row gt_right">0.564</td>
# <td headers="Population Size (Below 1 million) stub_2_11 Class.2.mean" class="gt_row gt_right">0.913</td>
# <td headers="Population Size (Below 1 million) stub_2_11 Class.3.mean" class="gt_row gt_right">0.569</td></tr>
#     <tr class="gt_row_group_first"><td headers="Mandatory Expenses (none) stub_2_12 stub_1" rowspan="3" class="gt_row gt_left gt_stub_row_group">Mandatory Expenses (none)</td>
# <th id="stub_2_12" scope="row" class="gt_row gt_left gt_stub">$0.01 - $200</th>
# <td headers="Mandatory Expenses (none) stub_2_12 Class.1.mean" class="gt_row gt_right">0.383</td>
# <td headers="Mandatory Expenses (none) stub_2_12 Class.2.mean" class="gt_row gt_right">0.386</td>
# <td headers="Mandatory Expenses (none) stub_2_12 Class.3.mean" class="gt_row gt_right">0.555</td></tr>
#     <tr><th id="stub_2_13" scope="row" class="gt_row gt_left gt_stub">$200.01 - $500</th>
# <td headers="Mandatory Expenses (none) stub_2_13 Class.1.mean" class="gt_row gt_right">0.321</td>
# <td headers="Mandatory Expenses (none) stub_2_13 Class.2.mean" class="gt_row gt_right">0.259</td>
# <td headers="Mandatory Expenses (none) stub_2_13 Class.3.mean" class="gt_row gt_right">0.110</td></tr>
#     <tr><th id="stub_2_14" scope="row" class="gt_row gt_left gt_stub">&gt; $500</th>
# <td headers="Mandatory Expenses (none) stub_2_14 Class.1.mean" class="gt_row gt_right">0.242</td>
# <td headers="Mandatory Expenses (none) stub_2_14 Class.2.mean" class="gt_row gt_right">0.221</td>
# <td headers="Mandatory Expenses (none) stub_2_14 Class.3.mean" class="gt_row gt_right">0.036</td></tr>
#     <tr class="gt_row_group_first"><td headers="House Expenses (none) stub_2_15 stub_1" rowspan="3" class="gt_row gt_left gt_stub_row_group">House Expenses (none)</td>
# <th id="stub_2_15" scope="row" class="gt_row gt_left gt_stub">$0.01 - $200</th>
# <td headers="House Expenses (none) stub_2_15 Class.1.mean" class="gt_row gt_right">0.310</td>
# <td headers="House Expenses (none) stub_2_15 Class.2.mean" class="gt_row gt_right">0.401</td>
# <td headers="House Expenses (none) stub_2_15 Class.3.mean" class="gt_row gt_right">0.486</td></tr>
#     <tr><th id="stub_2_16" scope="row" class="gt_row gt_left gt_stub">$200.01 - $500</th>
# <td headers="House Expenses (none) stub_2_16 Class.1.mean" class="gt_row gt_right">0.216</td>
# <td headers="House Expenses (none) stub_2_16 Class.2.mean" class="gt_row gt_right">0.176</td>
# <td headers="House Expenses (none) stub_2_16 Class.3.mean" class="gt_row gt_right">0.112</td></tr>
#     <tr><th id="stub_2_17" scope="row" class="gt_row gt_left gt_stub">&gt; $500</th>
# <td headers="House Expenses (none) stub_2_17 Class.1.mean" class="gt_row gt_right">0.458</td>
# <td headers="House Expenses (none) stub_2_17 Class.2.mean" class="gt_row gt_right">0.282</td>
# <td headers="House Expenses (none) stub_2_17 Class.3.mean" class="gt_row gt_right">0.124</td></tr>
#     <tr class="gt_row_group_first"><td headers="Food Expenses (<$100) stub_2_18 stub_1" rowspan="2" class="gt_row gt_left gt_stub_row_group">Food Expenses (&lt;$100)</td>
# <th id="stub_2_18" scope="row" class="gt_row gt_left gt_stub">$100.01 - $500</th>
# <td headers="Food Expenses (<$100) stub_2_18 Class.1.mean" class="gt_row gt_right">0.487</td>
# <td headers="Food Expenses (<$100) stub_2_18 Class.2.mean" class="gt_row gt_right">0.516</td>
# <td headers="Food Expenses (<$100) stub_2_18 Class.3.mean" class="gt_row gt_right">0.665</td></tr>
#     <tr><th id="stub_2_19" scope="row" class="gt_row gt_left gt_stub">&gt;$500</th>
# <td headers="Food Expenses (<$100) stub_2_19 Class.1.mean" class="gt_row gt_right">0.481</td>
# <td headers="Food Expenses (<$100) stub_2_19 Class.2.mean" class="gt_row gt_right">0.442</td>
# <td headers="Food Expenses (<$100) stub_2_19 Class.3.mean" class="gt_row gt_right">0.113</td></tr>
#     <tr class="gt_row_group_first"><td headers="Leisure Expenses (none) stub_2_20 stub_1" rowspan="2" class="gt_row gt_left gt_stub_row_group">Leisure Expenses (none)</td>
# <th id="stub_2_20" scope="row" class="gt_row gt_left gt_stub">$0.01 - $100</th>
# <td headers="Leisure Expenses (none) stub_2_20 Class.1.mean" class="gt_row gt_right">0.233</td>
# <td headers="Leisure Expenses (none) stub_2_20 Class.2.mean" class="gt_row gt_right">0.266</td>
# <td headers="Leisure Expenses (none) stub_2_20 Class.3.mean" class="gt_row gt_right">0.237</td></tr>
#     <tr><th id="stub_2_21" scope="row" class="gt_row gt_left gt_stub">&gt;$100</th>
# <td headers="Leisure Expenses (none) stub_2_21 Class.1.mean" class="gt_row gt_right">0.632</td>
# <td headers="Leisure Expenses (none) stub_2_21 Class.2.mean" class="gt_row gt_right">0.508</td>
# <td headers="Leisure Expenses (none) stub_2_21 Class.3.mean" class="gt_row gt_right">0.184</td></tr>
#   </tbody>
#
# </table>
# </div>
#
# Table 10: The table that Katie gave me the code to make.
#
# ## 5 References
#
# Amirnazmiafshar, Ehsan, and Marco Diana. 2022. “A Review of the Socio-Demographic Characteristics Affecting the Demand for Different Car-Sharing Operational Schemes.” *Transportation Research Interdisciplinary Perspectives* 14 (June): 100616. <https://doi.org/10.1016/j.trip.2022.100616>.
#
# Bernardo, Christina, Rajesh Paleti, Megan Hoklas, and Chandra Bhat. 2015. “An Empirical Investigation into the Time-Use and Activity Patterns of Dual-Earner Couples with and Without Young Children.” *Transportation Research Part A: Policy and Practice* 76 (June): 71–91. <https://doi.org/10.1016/j.tra.2014.12.006>.
#
# Bilgin, Pinar, Giulio Mattioli, Malcolm Morgan, and Zia Wadud. 2025. “Investigating the Effects of Ridesourcing on the Dynamics of Household Car Ownership.” *Transportation Research Part D: Transport and Environment* 146 (September): 104886. <https://doi.org/10.1016/j.trd.2025.104886>.
#
# Blumenberg, Evelyn. 2003. *Transportation Costs and Economic Opportunity Among the Poor*. October.
#
# Bureau of Transportation Statistics. 2024. *Transportation Statistics Annual Report 2024*. Bureau of Transportation Statistics. <https://doi.org/10.21949/E0KQ-GF72>.
#
# Choo, Sangho, Taihyeong Lee, and Patricia L. Mokhtarian. 2007. “Do Transportation and Communications Tend to Be Substitutes, Complements, or Neither?: U.S. Consumer Expenditures Perspective, 1984–2002.” *Transportation Research Record* 2010 (1): 121–32. <https://doi.org/10.3141/2010-14>.
#
# Copperman, Rachel B., and Chandra R. Bhat. 2007a. “An Analysis of the Determinants of Children’s Weekend Physical Activity Participation.” *Transportation* 34 (1): 67–87. <https://doi.org/10.1007/s11116-006-0005-5>.
#
# Copperman, Rachel B, and Chandra R Bhat. 2007b. *An Exploratory Analysis of Children’s Daily Time-Use and Activity Patterns Using the Child Development Supplement (CDS) to the US Panel Study of Income Dynamics (PSID)*.
#
# Deka, Devajyoti. 2015. “Relationship Between Households’ Housing and Transportation Expenditures: Examination from Lifestyle Perspective.” *Transportation Research Record* 2531 (1): 26–35. <https://doi.org/10.3141/2531-04>.
#
# Duncan, Karen A., Kristyn Frank, and Anne Guèvremont. 2023. *Estimating Expenditures on Children by Families in Canada, 2014 to 2017*. September. <https://doi.org/10.25318/11F0019M2023007-ENG>.
#
# Ferdous, Nazneen, Abdul Rawoof Pinjari, Chandra R. Bhat, and Ram M. Pendyala. 2010. “A Comprehensive Analysis of Household Transportation Expenditures Relative to Other Goods and Services: An Application to United States Consumer Expenditure Data.” *Transportation* 37 (3): 363–90. <https://doi.org/10.1007/s11116-010-9264-2>.
#
# Fontes, Angela, and Jessie Fan. 2006. “The Effects of Ethnic Identity on Household Budget Allocation to Status Conveying Goods.” *Journal of Family and Economic Issues* 27 (February): 643–63. <https://doi.org/10.1007/s10834-006-9031-x>.
#
# Haas, Peter M., Carrie Makarewicz, Albert Benedict, and Scott Bernstein. 2008. “Estimating Transportation Costs by Characteristics of Neighborhood and Household.” *Transportation Research Record* 2077 (1): 62–70. <https://doi.org/10.3141/2077-09>.
#
# Hargunani, Chahat, Sachin Vernekar, and Shradha Vernekar. 2024. *A STUDY OF SPENDING, SAVING AND INVESTMENT PATTERNS OF MARRIED COUPLES WITH CHILDREN(NON-DINK) IN MUMBAI*. 20 (1).
#
# Hastings, Orestes P. 2022. “Parental Investments of Money for White, Black, and Hispanic Children in the United States.” *Socius: Sociological Research for a Dynamic World* 8 (January): 23780231221103054. <https://doi.org/10.1177/23780231221103054>.
#
# Hong, Gong-Soog, Jessie X. Fan, Lance Palmer, and Vibha Bhargava. 2005. “Leisure Travel Expenditure Patterns by Family Life Cycle Stages.” *Journal of Travel & Tourism Marketing* 18 (2): 15–30. <https://doi.org/10.1300/J073v18n02_02>.
#
# Johnson, David S., John M. Rogers, and Lucilla Tan. 2001. “A Century of Family Budgets in the United States.” *Monthly Labor Review* 124 (5): 28–45. <https://heinonline.org/HOL/P?h=hein.journals/month124&i=482>.
#
# Klein, Nicholas J. 2024. “Subsidizing Car Ownership for Low-Income Individuals and Households.” *Journal of Planning Education and Research* 44 (1): 165–77. <https://doi.org/10.1177/0739456X20950428>.
#
# Leung, Kevin Y. K., Sebastian Astroza, Becky P. Y. Loo, and Chandra R. Bhat. 2019. “An Environment-People Interactions Framework for Analysing Children’s Extra-Curricular Activities and Active Transport.” *Journal of Transport Geography* 74 (January): 341–58. <https://doi.org/10.1016/j.jtrangeo.2018.12.015>.
#
# Lino, Mark, Kevin Kuczynski, Nestor Rodriguez, and TusaRebecca Schap. 2017. *Expenditures on Children by Families, 2015*. United States Department of Agriculture. <https://doi.org/10.22004/ag.econ.327257>.
#
# Lu, Ying, Carlo G. Prato, Neil Sipe, Anthony Kimpton, and Jonathan Corcoran. 2022. “The Role of Household Modality Style in First and Last Mile Travel Mode Choice.” *Transportation Research Part A: Policy and Practice* 158 (April): 95–109. <https://doi.org/10.1016/j.tra.2022.02.003>.
#
# Mattson, Jeremy. 2020. “Relationships Between Density, Transit, and Household Expenditures in Small Urban Areas.” *Transportation Research Interdisciplinary Perspectives* 8 (November): 100260. <https://doi.org/10.1016/j.trip.2020.100260>.
#
# Mattson, Jeremy, and Del Peterson. 2019. *Relationships Between Land Use, Transportation, Household Expenditures, and Municipal Spending in Small Urban Areas*. December.
#
# McCarthy, Laura, Alexa Delbosc, Graham Currie, and Andrew Molloy. 2017. “Factors Influencing Travel Mode Choice Among Families with Young Children (Aged 0–4): A Review of the Literature.” *Transport Reviews* 37 (6): 767–81. <https://doi.org/10.1080/01441647.2017.1354942>.
#
# Molloy, Quinn, Norman Garrick, and Carol Atkinson-Palombo. 2024. “A New Approach to Understanding the Impact of Automobile Ownership on Transportation Equity.” *Transportation Research Record* 2678 (2): 366–76. <https://doi.org/10.1177/03611981231174444>.
#
# Morris, J. M., and M. R. Wigan. 1979. “A Family Expenditure Perspective on Transport Planning: Australian Evidence in Context.” *Transportation Research Part A: General* 13 (4): 249–85. <https://doi.org/10.1016/0191-2607(79)90051-7>.
#
# Nayga, Rodolfo M. 1998. “A Sample Selection Model for Prepared Food Expenditures.” *Applied Economics* 30 (3): 345–52. <https://doi.org/10.1080/000368498325868>.
#
# Osborne, Cynthia, Erin Wu, and Kaeley Benson. 2021. *An Updated Estimation Model of the Cost of Raising Children in Texas*.
#
# Paleti, Rajesh, Rachel B. Copperman, and Chandra R. Bhat. 2011. “An Empirical Analysis of Children’s After School Out-of-Home Activity-Location Engagement Patterns and Time Allocation.” *Transportation* 38 (2): 273–303. <https://doi.org/10.1007/s11116-010-9300-2>.
#
# Sabelhaus, John, David Johnson, Stephen Ash, et al. 2013. *Is the Consumer Expenditure Survey Representative by Income?* No. w19589. National Bureau of Economic Research. <https://doi.org/10.3386/w19589>.
#
# Sener, Ipek N., and Chandra R. Bhat. 2007. “An Analysis of the Social Context of Children’s Weekend Discretionary Activity Participation.” *Transportation* 34 (6): 697–721. <https://doi.org/10.1007/s11116-007-9125-9>.
#
# Sener, Ipek N., Rachel B. Copperman, Ram M. Pendyala, and Chandra R. Bhat. 2008. “An Analysis of Children’s Leisure Activity Engagement: Examining the Day of Week, Location, Physical Activity Level, and Fixity Dimensions.” *Transportation* 35 (5): 673–96. <https://doi.org/10.1007/s11116-008-9173-9>.
#
# Skinner, Jonathan. 1985. “Variable Lifespan and the Intertemporal Elasticity of Consumption.” *The Review of Economics and Statistics* 67 (4): 616–23. <https://doi.org/10.2307/1924806>.
#
# Souche, Stéphanie. 2010. “Measuring the Structural Determinants of Urban Travel Demand.” *Transport Policy* 17 (3): 127–34. <https://doi.org/10.1016/j.tranpol.2009.12.003>.
#
# Thakuriah, Piyushimita (Vonu), and Yihua Liao. 2005. “Analysis of Variations in Vehicle Ownership Expenditures.” *Transportation Research Record: Journal of the Transportation Research Board* 1926 (1): 1–9. <https://doi.org/10.1177/0361198105192600101>.
#
# Thakuriah (Vonu), Piyushimita, and Yihua Liao. 2006. “Transportation Expenditures and Ability to Pay: Evidence from Consumer Expenditure Survey.” *Transportation Research Record* 1985 (1): 257–65. <https://doi.org/10.1177/0361198106198500128>.
#
# ## 6 Appendix A: Spending Category Breakdown

# %%
detailed_cats <- ucc_codes |>
  select(ucc_code, `Code description`, broad_category)

names(detailed_cats) <- c("UCC Code","Code Description","Category")

detailed_cats |> 
  gt(
    # rowname_col = "UCC Code",
     groupname_col = "Category",
     row_group_as_column = TRUE)
